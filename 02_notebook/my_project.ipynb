# %% [markdown]
# in the folder: experiment > differents params configuration (also the ID), output > several run saved with hydra file containing the parameters changed in params configuration

# %% [markdown]
# # Notebook 2
#
# - If you work on Google Colab, [![open In Colab](https://colab.research.google.com/assets/colab-badge.svg)](
# https://colab.research.google.com/github/jouvetg/glamod/blob/main/02_notebook/glacier-modelling-2.ipynb) and you will donwload the repo  below. Make sure to activate the GPU on Colab "Runtime" -> "Change Runtime Type" -> Slect GPU.
#
# - If you work locally on your own PC, you can download the repo
# ```bash
# git clone --depth 1 https://github.com/jouvetg/glamod.git
# ```
# and then go the notebook folder, and work from there.

# %% [markdown]
# ## Goals of this notebook
#
#    - Get familiar with model IGM
#    - Understand the parameters, set-up your model
#    - Run IGM examples
#    - Customization, run IGM for your own glacier

# %% [markdown]
# ## What is IGM?
#
# Here we will use the glacier evolution model developed at UNIL -- the Instructed Glacier Model.
#
# The IGM is an open-source Python package, which permits to simulate 3D glacier evolution accounting for the coupling between ice thermo-dynamics, surface mass balance, and mass conservation. IGM is especially computationally efficient thanks to the TensorFlow library, mathematical operations are fully-vectorized. This permits important speed-ups on [GPU](https://en.wikipedia.org/wiki/Graphics_processing_unit) (Graphics Processing Units), which are devices made of many processors, and can therefore perform highly-parallelized computations.
#
# All the documentation can be found at [https://igm-model.org/](https://igm-model.org/).

# %% [markdown]
# ## How to install IGM?
#
# Running IGM consists of running a python script `igm_run`, which is made of functions of the `igm` python package.  First of all, one needs to install igm as follows: (this may take a while, and it may crashes the first time, but should work the second time).

# %%
! pip install -i https://test.pypi.org/simple/ --extra-index-url https://pypi.org/simple igm-model-testing-package==3.0.5
! pip install ml-dtypes==0.5.3
# Out:
# Looking in indexes: https://test.pypi.org/simple/, https://pypi.org/simple
# Requirement already satisfied: igm-model-testing-package==3.0.5 in /usr/local/lib/python3.12/dist-packages (3.0.5)
# Requirement already satisfied: tensorflow==2.17.1 in /usr/local/lib/python3.12/dist-packages (from tensorflow[and-cuda]==2.17.1->igm-model-testing-package==3.0.5) (2.17.1)
# Requirement already satisfied: matplotlib in /usr/local/lib/python3.12/dist-packages (from igm-model-testing-package==3.0.5) (3.10.0)
# Requirement already satisfied: scipy in /usr/local/lib/python3.12/dist-packages (from igm-model-testing-package==3.0.5) (1.16.2)
# Requirement already satisfied: netCDF4==1.6.0 in /usr/local/lib/python3.12/dist-packages (from igm-model-testing-package==3.0.5) (1.6.0)
# Requirement already satisfied: xarray in /usr/local/lib/python3.12/dist-packages (from igm-model-testing-package==3.0.5) (2025.10.1)
# Requirement already satisfied: rasterio in /usr/local/lib/python3.12/dist-packages (from igm-model-testing-package==3.0.5) (1.4.3)
# Requirement already satisfied: pyproj in /usr/local/lib/python3.12/dist-packages (from igm-model-testing-package==3.0.5) (3.7.2)
# Requirement already satisfied: geopandas in /usr/local/lib/python3.12/dist-packages (from igm-model-testing-package==3.0.5) (1.1.1)
# Requirement already satisfied: oggm in /usr/local/lib/python3.12/dist-packages (from igm-model-testing-package==3.0.5) (1.6.2)
# Requirement already satisfied: salem in /usr/local/lib/python3.12/dist-packages (from igm-model-testing-package==3.0.5) (0.3.11)
# Requirement already satisfied: pyyaml in /usr/local/lib/python3.12/dist-packages (from igm-model-testing-package==3.0.5) (6.0.3)
# Requirement already satisfied: importlib_resources in /usr/local/lib/python3.12/dist-packages (from igm-model-testing-package==3.0.5) (6.5.2)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.12/dist-packages (from igm-model-testing-package==3.0.5) (4.67.1)
# Requirement already satisfied: hydra-core in /usr/local/lib/python3.12/dist-packages (from igm-model-testing-package==3.0.5) (1.3.2)
# Requirement already satisfied: omegaconf in /usr/local/lib/python3.12/dist-packages (from igm-model-testing-package==3.0.5) (2.3.0)
# Requirement already satisfied: numpy>=1.9 in /usr/local/lib/python3.12/dist-packages (from netCDF4==1.6.0->igm-model-testing-package==3.0.5) (1.26.4)
# Requirement already satisfied: cftime in /usr/local/lib/python3.12/dist-packages (from netCDF4==1.6.0->igm-model-testing-package==3.0.5) (1.6.5)
# Requirement already satisfied: absl-py>=1.0.0 in /usr/local/lib/python3.12/dist-packages (from tensorflow==2.17.1->tensorflow[and-cuda]==2.17.1->igm-model-testing-package==3.0.5) (1.4.0)
# Requirement already satisfied: astunparse>=1.6.0 in /usr/local/lib/python3.12/dist-packages (from tensorflow==2.17.1->tensorflow[and-cuda]==2.17.1->igm-model-testing-package==3.0.5) (1.6.3)
# Requirement already satisfied: flatbuffers>=24.3.25 in /usr/local/lib/python3.12/dist-packages (from tensorflow==2.17.1->tensorflow[and-cuda]==2.17.1->igm-model-testing-package==3.0.5) (25.9.23)
# Requirement already satisfied: gast!=0.5.0,!=0.5.1,!=0.5.2,>=0.2.1 in /usr/local/lib/python3.12/dist-packages (from tensorflow==2.17.1->tensorflow[and-cuda]==2.17.1->igm-model-testing-package==3.0.5) (0.6.0)
# Requirement already satisfied: google-pasta>=0.1.1 in /usr/local/lib/python3.12/dist-packages (from tensorflow==2.17.1->tensorflow[and-cuda]==2.17.1->igm-model-testing-package==3.0.5) (0.2.0)
# Requirement already satisfied: h5py>=3.10.0 in /usr/local/lib/python3.12/dist-packages (from tensorflow==2.17.1->tensorflow[and-cuda]==2.17.1->igm-model-testing-package==3.0.5) (3.15.1)
# Requirement already satisfied: libclang>=13.0.0 in /usr/local/lib/python3.12/dist-packages (from tensorflow==2.17.1->tensorflow[and-cuda]==2.17.1->igm-model-testing-package==3.0.5) (18.1.1)
# Collecting ml-dtypes<0.5.0,>=0.3.1 (from tensorflow==2.17.1->tensorflow[and-cuda]==2.17.1->igm-model-testing-package==3.0.5)
#   Using cached ml_dtypes-0.4.1-cp312-cp312-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (20 kB)
# Requirement already satisfied: opt-einsum>=2.3.2 in /usr/local/lib/python3.12/dist-packages (from tensorflow==2.17.1->tensorflow[and-cuda]==2.17.1->igm-model-testing-package==3.0.5) (3.4.0)
# Requirement already satisfied: packaging in /usr/local/lib/python3.12/dist-packages (from tensorflow==2.17.1->tensorflow[and-cuda]==2.17.1->igm-model-testing-package==3.0.5) (25.0)
# Requirement already satisfied: protobuf!=4.21.0,!=4.21.1,!=4.21.2,!=4.21.3,!=4.21.4,!=4.21.5,<5.0.0dev,>=3.20.3 in /usr/local/lib/python3.12/dist-packages (from tensorflow==2.17.1->tensorflow[and-cuda]==2.17.1->igm-model-testing-package==3.0.5) (4.25.8)
# Requirement already satisfied: requests<3,>=2.21.0 in /usr/local/lib/python3.12/dist-packages (from tensorflow==2.17.1->tensorflow[and-cuda]==2.17.1->igm-model-testing-package==3.0.5) (2.32.4)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.12/dist-packages (from tensorflow==2.17.1->tensorflow[and-cuda]==2.17.1->igm-model-testing-package==3.0.5) (75.2.0)
# Requirement already satisfied: six>=1.12.0 in /usr/local/lib/python3.12/dist-packages (from tensorflow==2.17.1->tensorflow[and-cuda]==2.17.1->igm-model-testing-package==3.0.5) (1.17.0)
# Requirement already satisfied: termcolor>=1.1.0 in /usr/local/lib/python3.12/dist-packages (from tensorflow==2.17.1->tensorflow[and-cuda]==2.17.1->igm-model-testing-package==3.0.5) (3.1.0)
# Requirement already satisfied: typing-extensions>=3.6.6 in /usr/local/lib/python3.12/dist-packages (from tensorflow==2.17.1->tensorflow[and-cuda]==2.17.1->igm-model-testing-package==3.0.5) (4.15.0)
# Requirement already satisfied: wrapt>=1.11.0 in /usr/local/lib/python3.12/dist-packages (from tensorflow==2.17.1->tensorflow[and-cuda]==2.17.1->igm-model-testing-package==3.0.5) (2.0.0)
# Requirement already satisfied: grpcio<2.0,>=1.24.3 in /usr/local/lib/python3.12/dist-packages (from tensorflow==2.17.1->tensorflow[and-cuda]==2.17.1->igm-model-testing-package==3.0.5) (1.76.0)
# Requirement already satisfied: tensorboard<2.18,>=2.17 in /usr/local/lib/python3.12/dist-packages (from tensorflow==2.17.1->tensorflow[and-cuda]==2.17.1->igm-model-testing-package==3.0.5) (2.17.1)
# Requirement already satisfied: keras>=3.2.0 in /usr/local/lib/python3.12/dist-packages (from tensorflow==2.17.1->tensorflow[and-cuda]==2.17.1->igm-model-testing-package==3.0.5) (3.10.0)
# Requirement already satisfied: nvidia-cublas-cu12==12.3.4.1 in /usr/local/lib/python3.12/dist-packages (from tensorflow[and-cuda]==2.17.1->igm-model-testing-package==3.0.5) (12.3.4.1)
# Requirement already satisfied: nvidia-cuda-cupti-cu12==12.3.101 in /usr/local/lib/python3.12/dist-packages (from tensorflow[and-cuda]==2.17.1->igm-model-testing-package==3.0.5) (12.3.101)
# Requirement already satisfied: nvidia-cuda-nvcc-cu12==12.3.107 in /usr/local/lib/python3.12/dist-packages (from tensorflow[and-cuda]==2.17.1->igm-model-testing-package==3.0.5) (12.3.107)
# Requirement already satisfied: nvidia-cuda-nvrtc-cu12==12.3.107 in /usr/local/lib/python3.12/dist-packages (from tensorflow[and-cuda]==2.17.1->igm-model-testing-package==3.0.5) (12.3.107)
# Requirement already satisfied: nvidia-cuda-runtime-cu12==12.3.101 in /usr/local/lib/python3.12/dist-packages (from tensorflow[and-cuda]==2.17.1->igm-model-testing-package==3.0.5) (12.3.101)
# Requirement already satisfied: nvidia-cudnn-cu12==8.9.7.29 in /usr/local/lib/python3.12/dist-packages (from tensorflow[and-cuda]==2.17.1->igm-model-testing-package==3.0.5) (8.9.7.29)
# Requirement already satisfied: nvidia-cufft-cu12==11.0.12.1 in /usr/local/lib/python3.12/dist-packages (from tensorflow[and-cuda]==2.17.1->igm-model-testing-package==3.0.5) (11.0.12.1)
# Requirement already satisfied: nvidia-curand-cu12==10.3.4.107 in /usr/local/lib/python3.12/dist-packages (from tensorflow[and-cuda]==2.17.1->igm-model-testing-package==3.0.5) (10.3.4.107)
# Requirement already satisfied: nvidia-cusolver-cu12==11.5.4.101 in /usr/local/lib/python3.12/dist-packages (from tensorflow[and-cuda]==2.17.1->igm-model-testing-package==3.0.5) (11.5.4.101)
# Requirement already satisfied: nvidia-cusparse-cu12==12.2.0.103 in /usr/local/lib/python3.12/dist-packages (from tensorflow[and-cuda]==2.17.1->igm-model-testing-package==3.0.5) (12.2.0.103)
# Requirement already satisfied: nvidia-nccl-cu12==2.19.3 in /usr/local/lib/python3.12/dist-packages (from tensorflow[and-cuda]==2.17.1->igm-model-testing-package==3.0.5) (2.19.3)
# Requirement already satisfied: nvidia-nvjitlink-cu12==12.3.101 in /usr/local/lib/python3.12/dist-packages (from tensorflow[and-cuda]==2.17.1->igm-model-testing-package==3.0.5) (12.3.101)
# Requirement already satisfied: pyogrio>=0.7.2 in /usr/local/lib/python3.12/dist-packages (from geopandas->igm-model-testing-package==3.0.5) (0.11.1)
# Requirement already satisfied: pandas>=2.0.0 in /usr/local/lib/python3.12/dist-packages (from geopandas->igm-model-testing-package==3.0.5) (2.2.2)
# Requirement already satisfied: shapely>=2.0.0 in /usr/local/lib/python3.12/dist-packages (from geopandas->igm-model-testing-package==3.0.5) (2.1.2)
# Requirement already satisfied: certifi in /usr/local/lib/python3.12/dist-packages (from pyproj->igm-model-testing-package==3.0.5) (2025.10.5)
# Requirement already satisfied: antlr4-python3-runtime==4.9.* in /usr/local/lib/python3.12/dist-packages (from hydra-core->igm-model-testing-package==3.0.5) (4.9.3)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib->igm-model-testing-package==3.0.5) (1.3.3)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.12/dist-packages (from matplotlib->igm-model-testing-package==3.0.5) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.12/dist-packages (from matplotlib->igm-model-testing-package==3.0.5) (4.60.1)
# Requirement already satisfied: kiwisolver>=1.3.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib->igm-model-testing-package==3.0.5) (1.4.9)
# Requirement already satisfied: pillow>=8 in /usr/local/lib/python3.12/dist-packages (from matplotlib->igm-model-testing-package==3.0.5) (11.3.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib->igm-model-testing-package==3.0.5) (3.2.5)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.12/dist-packages (from matplotlib->igm-model-testing-package==3.0.5) (2.9.0.post0)
# Requirement already satisfied: configobj in /usr/local/lib/python3.12/dist-packages (from oggm->igm-model-testing-package==3.0.5) (5.0.9)
# Requirement already satisfied: affine in /usr/local/lib/python3.12/dist-packages (from rasterio->igm-model-testing-package==3.0.5) (2.4.0)
# Requirement already satisfied: attrs in /usr/local/lib/python3.12/dist-packages (from rasterio->igm-model-testing-package==3.0.5) (25.4.0)
# Requirement already satisfied: click>=4.0 in /usr/local/lib/python3.12/dist-packages (from rasterio->igm-model-testing-package==3.0.5) (8.3.0)
# Requirement already satisfied: cligj>=0.5 in /usr/local/lib/python3.12/dist-packages (from rasterio->igm-model-testing-package==3.0.5) (0.7.2)
# Requirement already satisfied: click-plugins in /usr/local/lib/python3.12/dist-packages (from rasterio->igm-model-testing-package==3.0.5) (1.1.1.2)
# Requirement already satisfied: joblib in /usr/local/lib/python3.12/dist-packages (from salem->igm-model-testing-package==3.0.5) (1.5.2)
# Requirement already satisfied: wheel<1.0,>=0.23.0 in /usr/local/lib/python3.12/dist-packages (from astunparse>=1.6.0->tensorflow==2.17.1->tensorflow[and-cuda]==2.17.1->igm-model-testing-package==3.0.5) (0.45.1)
# Requirement already satisfied: rich in /usr/local/lib/python3.12/dist-packages (from keras>=3.2.0->tensorflow==2.17.1->tensorflow[and-cuda]==2.17.1->igm-model-testing-package==3.0.5) (13.9.4)
# Requirement already satisfied: namex in /usr/local/lib/python3.12/dist-packages (from keras>=3.2.0->tensorflow==2.17.1->tensorflow[and-cuda]==2.17.1->igm-model-testing-package==3.0.5) (0.1.0)
# Requirement already satisfied: optree in /usr/local/lib/python3.12/dist-packages (from keras>=3.2.0->tensorflow==2.17.1->tensorflow[and-cuda]==2.17.1->igm-model-testing-package==3.0.5) (0.17.0)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.12/dist-packages (from pandas>=2.0.0->geopandas->igm-model-testing-package==3.0.5) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.12/dist-packages (from pandas>=2.0.0->geopandas->igm-model-testing-package==3.0.5) (2025.2)
# Requirement already satisfied: charset_normalizer<4,>=2 in /usr/local/lib/python3.12/dist-packages (from requests<3,>=2.21.0->tensorflow==2.17.1->tensorflow[and-cuda]==2.17.1->igm-model-testing-package==3.0.5) (3.4.4)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.12/dist-packages (from requests<3,>=2.21.0->tensorflow==2.17.1->tensorflow[and-cuda]==2.17.1->igm-model-testing-package==3.0.5) (3.11)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.12/dist-packages (from requests<3,>=2.21.0->tensorflow==2.17.1->tensorflow[and-cuda]==2.17.1->igm-model-testing-package==3.0.5) (2.5.0)
# Requirement already satisfied: markdown>=2.6.8 in /usr/local/lib/python3.12/dist-packages (from tensorboard<2.18,>=2.17->tensorflow==2.17.1->tensorflow[and-cuda]==2.17.1->igm-model-testing-package==3.0.5) (3.9)
# Requirement already satisfied: tensorboard-data-server<0.8.0,>=0.7.0 in /usr/local/lib/python3.12/dist-packages (from tensorboard<2.18,>=2.17->tensorflow==2.17.1->tensorflow[and-cuda]==2.17.1->igm-model-testing-package==3.0.5) (0.7.2)
# Requirement already satisfied: werkzeug>=1.0.1 in /usr/local/lib/python3.12/dist-packages (from tensorboard<2.18,>=2.17->tensorflow==2.17.1->tensorflow[and-cuda]==2.17.1->igm-model-testing-package==3.0.5) (3.1.3)
# Requirement already satisfied: MarkupSafe>=2.1.1 in /usr/local/lib/python3.12/dist-packages (from werkzeug>=1.0.1->tensorboard<2.18,>=2.17->tensorflow==2.17.1->tensorflow[and-cuda]==2.17.1->igm-model-testing-package==3.0.5) (3.0.3)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /usr/local/lib/python3.12/dist-packages (from rich->keras>=3.2.0->tensorflow==2.17.1->tensorflow[and-cuda]==2.17.1->igm-model-testing-package==3.0.5) (4.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /usr/local/lib/python3.12/dist-packages (from rich->keras>=3.2.0->tensorflow==2.17.1->tensorflow[and-cuda]==2.17.1->igm-model-testing-package==3.0.5) (2.19.2)
# Requirement already satisfied: mdurl~=0.1 in /usr/local/lib/python3.12/dist-packages (from markdown-it-py>=2.2.0->rich->keras>=3.2.0->tensorflow==2.17.1->tensorflow[and-cuda]==2.17.1->igm-model-testing-package==3.0.5) (0.1.2)
# Using cached ml_dtypes-0.4.1-cp312-cp312-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (2.2 MB)
# Installing collected packages: ml-dtypes
#   Attempting uninstall: ml-dtypes
#     Found existing installation: ml_dtypes 0.5.3
#     Uninstalling ml_dtypes-0.5.3:
#       Successfully uninstalled ml_dtypes-0.5.3
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# jax 0.7.2 requires ml_dtypes>=0.5.0, but you have ml-dtypes 0.4.1 which is incompatible.
# jax 0.7.2 requires numpy>=2.0, but you have numpy 1.26.4 which is incompatible.
# tensorflow-text 2.19.0 requires tensorflow<2.20,>=2.19.0, but you have tensorflow 2.17.1 which is incompatible.
# tf-keras 2.19.0 requires tensorflow<2.20,>=2.19, but you have tensorflow 2.17.1 which is incompatible.
# tensorstore 0.1.78 requires ml_dtypes>=0.5.0, but you have ml-dtypes 0.4.1 which is incompatible.
# jaxlib 0.7.2 requires ml_dtypes>=0.5.0, but you have ml-dtypes 0.4.1 which is incompatible.
# jaxlib 0.7.2 requires numpy>=2.0, but you have numpy 1.26.4 which is incompatible.
# tensorflow-decision-forests 1.12.0 requires tensorflow==2.19.0, but you have tensorflow 2.17.1 which is incompatible.
# Successfully installed ml-dtypes-0.4.1
# Collecting ml-dtypes==0.5.3
#   Using cached ml_dtypes-0.5.3-cp312-cp312-manylinux_2_27_x86_64.manylinux_2_28_x86_64.whl.metadata (8.9 kB)
# Requirement already satisfied: numpy>=1.21 in /usr/local/lib/python3.12/dist-packages (from ml-dtypes==0.5.3) (1.26.4)
# Using cached ml_dtypes-0.5.3-cp312-cp312-manylinux_2_27_x86_64.manylinux_2_28_x86_64.whl (4.9 MB)
# Installing collected packages: ml-dtypes
#   Attempting uninstall: ml-dtypes
#     Found existing installation: ml-dtypes 0.4.1
#     Uninstalling ml-dtypes-0.4.1:
#       Successfully uninstalled ml-dtypes-0.4.1
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# tensorflow 2.17.1 requires ml-dtypes<0.5.0,>=0.3.1, but you have ml-dtypes 0.5.3 which is incompatible.
# jax 0.7.2 requires numpy>=2.0, but you have numpy 1.26.4 which is incompatible.
# tensorflow-text 2.19.0 requires tensorflow<2.20,>=2.19.0, but you have tensorflow 2.17.1 which is incompatible.
# tf-keras 2.19.0 requires tensorflow<2.20,>=2.19, but you have tensorflow 2.17.1 which is incompatible.
# jaxlib 0.7.2 requires numpy>=2.0, but you have numpy 1.26.4 which is incompatible.
# tensorflow-decision-forests 1.12.0 requires tensorflow==2.19.0, but you have tensorflow 2.17.1 which is incompatible.
# Successfully installed ml-dtypes-0.5.3

# %% [markdown]
# In this notebook, we will explore 3 model runs with increasing complexity:
#
# - A first basic run with a simple surface mass balance model
# - A second one that works for any glacier, with a more elaborate SMB
# - A third with a user-defined SMB and particle tracking

# %% [markdown]
# ## Download the data

# %% [markdown]
# Let's now download the repo with the data if you are using Colab

# %%
import sys, os

if "google.colab" in sys.modules:
    print("Running in Colab: cloning repo...")
    # !git clone --depth 1 https://github.com/jouvetg/glamod.git
    # !apt-get install tree -q
else:
    print("Running locally: using local files.")
# Out:
# Running in Colab: cloning repo...
# Cloning into 'glamod'...
# remote: Enumerating objects: 70, done.
# remote: Counting objects: 100% (70/70), done.
# remote: Compressing objects: 100% (57/57), done.
# remote: Total 70 (delta 5), reused 57 (delta 5), pack-reused 0 (from 0)
# Receiving objects: 100% (70/70), 14.04 MiB | 39.49 MiB/s, done.
# Resolving deltas: 100% (5/5), done.
# Reading package lists...
# Building dependency tree...
# Reading state information...
# tree is already the newest version (2.0.2-1).
# 0 upgraded, 0 newly installed, 0 to remove and 38 not upgraded.

# %% [markdown]
# Let's now go the working folder

# %%
if "google.colab" in sys.modules:
    # %cd /content/glamod/02_notebook
# Out:
# /content/glamod/02_notebook

# %% [markdown]
# ## First run with IGM

# %% [markdown]
# ### Folder exploration
#
# Let us explore the directory with the following command:

# %%
# !tree
# Out:
# .
# ├── data
# │   ├── input-aletsch.nc
# │   ├── RGI2000-v7.0-G-11-02596
# │   │   ├── climate_historical.nc
# │   │   ├── COPDEM30
# │   │   │   ├── dem_source.txt
# │   │   │   └── dem.tif
# │   │   ├── COPDEM90
# │   │   │   ├── dem_source.txt
# │   │   │   └── dem.tif
# │   │   ├── dem_source.txt
# │   │   ├── dem.tif
# │   │   ├── diagnostics.json
# │   │   ├── downstream_line.pkl
# │   │   ├── elevation_band_flowline.csv
# │   │   ├── elevation_band_flowline_fixed_dx.csv
# │   │   ├── glacier_grid.json
# │   │   ├── glacier_mask.tif
# │   │   ├── glathida_data.csv
# │   │   ├── gridded_data.nc
# │   │   ├── intersects.tar.gz
# │   │   ├── inversion_flowlines.pkl
# │   │   ├── log.txt
# │   │   ├── mb_calib.json
# │   │   ├── NASADEM
# │   │   │   ├── dem_source.txt
# │   │   │   └── dem.tif
# │   │   └── outlines.tar.gz
# │   └── RGI60-11.01450
# │       ├── climate_historical.nc
# │       ├── dem_source.txt
# │       ├── dem.tif
# │       ├── diagnostics.json
# │       ├── downstream_line.pkl
# │       ├── elevation_band_flowline.csv
# │       ├── elevation_band_flowline_fixed_dx.csv
# │       ├── glacier_grid.json
# │       ├── gridded_data.nc
# │       ├── intersects.tar.gz
# │       ├── inversion_flowlines.pkl
# │       ├── inversion_input.pkl
# │       ├── inversion_output.pkl
# │       ├── log.txt
# │       ├── mb_calib.json
# │       ├── model_flowlines.pkl
# │       └── outlines.tar.gz
# ├── experiment
# │   ├── params_0.yaml
# │   ├── params_1.yaml
# │   ├── params_29oct.yaml
# │   └── params_2.yaml
# ├── glacier-modelling-29oct.ipynb
# ├── glacier-modelling-2.ipynb
# ├── glamod
# │   ├── 00_introduction
# │   │   ├── 00_introduction.md
# │   │   └── fig
# │   │       ├── AIF-CH.png
# │   │       ├── AIF-leger-lq.png
# │   │       ├── AIF-lq.png
# │   │       ├── AIF.png
# │   │       ├── aletsch.jpg
# │   │       ├── algo.gif
# │   │       ├── argen1.JPG
# │   │       ├── climbers2.jpg
# │   │       ├── cordonnier_lq.png
# │   │       ├── course_illu.png
# │   │       ├── Figure7.png
# │   │       ├── glacier-goo.png
# │   │       ├── gl-equations.png
# │   │       ├── gletsch-1856.jpg
# │   │       ├── leger2024-lq.png
# │   │       ├── leger2024.png
# │   │       ├── LGM-cities.jpg
# │   │       ├── mercanton.jpg
# │   │       ├── MESH.png
# │   │       ├── pic1.jpg
# │   │       ├── pic2.jpg
# │   │       ├── rhone-mod-lq.png
# │   │       ├── rhone-mod.png
# │   │       ├── rhone-mod-short.png
# │   │       ├── scheme_glacier.png
# │   │       ├── scheme-ice-shelf.png
# │   │       ├── scheme.png
# │   │       ├── shearing-sliding.png
# │   │       ├── SIA-profile.png
# │   │       ├── sia-vs-ssa.png
# │   │       ├── simple_glacierA.png
# │   │       ├── stress-strain-BuddJacka1989.png
# │   │       ├── till.png
# │   │       └── velocity-smb-rhone.png
# │   ├── 00_project
# │   │   └── project.md
# │   ├── 01_notebook
# │   │   ├── glacier-modelling-1.ipynb
# │   │   └── topg.txt
# │   ├── 02_notebook
# │   │   ├── data
# │   │   │   └── input-aletsch.nc
# │   │   ├── experiment
# │   │   │   ├── params_0.yaml
# │   │   │   ├── params_1.yaml
# │   │   │   ├── params_29oct.yaml
# │   │   │   └── params_2.yaml
# │   │   ├── glacier-modelling-2.ipynb
# │   │   ├── helper.py
# │   │   └── user
# │   │       ├── code
# │   │       │   └── processes
# │   │       │       └── mysmb.py
# │   │       └── conf
# │   │           └── processes
# │   │               └── mysmb.yaml
# │   ├── 0-clean.sh
# │   ├── 1-build-site.sh
# │   ├── 2-check-site.sh
# │   ├── 3-publish-site.sh
# │   ├── _config.yml
# │   ├── infos.md
# │   ├── _toc.yml
# │   └── zip-exercices.sh
# ├── helper.py
# ├── outputs
# │   └── 2025-10-29
# │       ├── 07-54-32
# │       │   ├── igm_run.log
# │       │   ├── output.nc
# │       │   ├── output_ts.nc
# │       │   ├── velbar_mag-1900.0.png
# │       │   ├── velbar_mag-1910.0.png
# │       │   ├── velbar_mag-1920.0.png
# │       │   ├── velbar_mag-1930.0.png
# │       │   ├── velbar_mag-1940.0.png
# │       │   ├── velbar_mag-1950.0.png
# │       │   ├── velbar_mag-1960.0.png
# │       │   ├── velbar_mag-1970.0.png
# │       │   ├── velbar_mag-1980.0.png
# │       │   ├── velbar_mag-1990.0.png
# │       │   └── velbar_mag-2000.0.png
# │       ├── 07-55-48
# │       │   ├── igm_run.log
# │       │   ├── output.nc
# │       │   ├── output_ts.nc
# │       │   ├── velbar_mag-1800.0.png
# │       │   ├── velbar_mag-1810.0.png
# │       │   ├── velbar_mag-1820.0.png
# │       │   ├── velbar_mag-1830.0.png
# │       │   ├── velbar_mag-1840.0.png
# │       │   ├── velbar_mag-1850.0.png
# │       │   ├── velbar_mag-1860.0.png
# │       │   ├── velbar_mag-1870.0.png
# │       │   ├── velbar_mag-1880.0.png
# │       │   ├── velbar_mag-1890.0.png
# │       │   ├── velbar_mag-1900.0.png
# │       │   ├── velbar_mag-1910.0.png
# │       │   ├── velbar_mag-1920.0.png
# │       │   ├── velbar_mag-1930.0.png
# │       │   ├── velbar_mag-1940.0.png
# │       │   ├── velbar_mag-1950.0.png
# │       │   ├── velbar_mag-1960.0.png
# │       │   ├── velbar_mag-1970.0.png
# │       │   ├── velbar_mag-1980.0.png
# │       │   ├── velbar_mag-1990.0.png
# │       │   ├── velbar_mag-2000.0.png
# │       │   ├── velbar_mag-2010.0.png
# │       │   ├── velbar_mag-2020.0.png
# │       │   ├── velbar_mag-2030.0.png
# │       │   ├── velbar_mag-2040.0.png
# │       │   ├── velbar_mag-2050.0.png
# │       │   ├── velbar_mag-2060.0.png
# │       │   ├── velbar_mag-2070.0.png
# │       │   ├── velbar_mag-2080.0.png
# │       │   ├── velbar_mag-2090.0.png
# │       │   └── velbar_mag-2100.0.png
# │       └── 08-01-24
# │           ├── igm_run.log
# │           ├── output.nc
# │           ├── output_ts.nc
# │           ├── trajectories
# │           │   ├── time.dat
# │           │   ├── topg.csv
# │           │   ├── traj-02000-00.csv
# │           │   ├── traj-02010-00.csv
# │           │   ├── traj-02020-00.csv
# │           │   ├── traj-02030-00.csv
# │           │   ├── traj-02040-00.csv
# │           │   ├── traj-02050-00.csv
# │           │   ├── traj-02060-00.csv
# │           │   ├── traj-02070-00.csv
# │           │   ├── traj-02080-00.csv
# │           │   ├── traj-02090-00.csv
# │           │   ├── traj-02100-00.csv
# │           │   ├── usurf-02000-00.csv
# │           │   ├── usurf-02010-00.csv
# │           │   ├── usurf-02020-00.csv
# │           │   ├── usurf-02030-00.csv
# │           │   ├── usurf-02040-00.csv
# │           │   ├── usurf-02050-00.csv
# │           │   ├── usurf-02060-00.csv
# │           │   ├── usurf-02070-00.csv
# │           │   ├── usurf-02080-00.csv
# │           │   ├── usurf-02090-00.csv
# │           │   └── usurf-02100-00.csv
# │           ├── velbar_mag-2000.0.png
# │           ├── velbar_mag-2010.0.png
# │           ├── velbar_mag-2020.0.png
# │           ├── velbar_mag-2030.0.png
# │           ├── velbar_mag-2040.0.png
# │           ├── velbar_mag-2050.0.png
# │           ├── velbar_mag-2060.0.png
# │           ├── velbar_mag-2070.0.png
# │           ├── velbar_mag-2080.0.png
# │           ├── velbar_mag-2090.0.png
# │           └── velbar_mag-2100.0.png
# ├── __pycache__
# │   └── helper.cpython-312.pyc
# └── user
#     ├── code
#     │   └── processes
#     │       ├── mysmb.py
#     │       └── __pycache__
#     │           └── mysmb.cpython-312.pyc
#     └── conf
#         └── processes
#             └── mysmb.yaml
#
# 33 directories, 192 files

# %% [markdown]
# You will see the following files :
#
# ```bash
# .
# ├── data                 # This folder contains all input data
# ├── experiment           # This folder contains the parameters
# │   ├── params_0.yaml
# │   ├── ...
# └── user                 # This folder contains user code
#     ├── code
#     └── conf
# ```

# %% [markdown]
# ### Parameter file exploration
#
# If you look at the parameter file, you will see the following content, which shows all the input, process, and output modules along with all their parameters. Below, you may notice that IGM: i) first loads a certain number of inputs, processes, and output modules, ii) second defines parameters associated with each module that deviate from default ones.
#
# Here is the content of `params_0.yaml`, taken from IGM's example `aletsch-basic`. Here, IGM loads data with the `local` module, proceeds to a simulation from 1900 to 2000 updating surface mass balance (`smb`), iceflow, time, and ice thickness. Then, it writes the results in both a local file (NetCDF file) and in the form of plots.
#
# ```yaml title="params_0.yaml"
# # @package _global_
#
# defaults:
#   - override /inputs:
#     - local                    # load local input module
#   - override /processes:
#     - smb_simple               # load smb_simple processes module
#     - iceflow                  # load iceflow processes module
#     - time                     # load time processes module
#     - thk                      # load thk processes module
#   - override /outputs:
#     - local                    # load local outputs module
#     - plot2d                   # load plot2d outputs module
#
# inputs:
#   local:
#      filename: input-aletsch.nc   # The local model will load the input-aletsch.nc file
#
# processes:
#   smb_simple:
#     array:
#       - ["time", "gradabl", "gradacc", "ela", "accmax"]
#       - [1900, 0.009, 0.005, 2800, 2.0]
#       - [2000, 0.009, 0.005, 2900, 2.0]
#       - [2100, 0.009, 0.005, 3300, 2.0]
#   time:
#     start: 1900.0
#     end: 2000.0
#     save: 10.0
#
# outputs:
#   plot2d:
#     live: False
# ```

# %% [markdown]
# IGM is organized **module-wise** as shown in the following flowchart:
#
# ![](https://igm-model.org/latest/modules/flowchat-module.png)
#
# As a user, you need to pick an ensemble of modules from existing ones (or you may create some user ones), and then define the parameters that deviate from default ones.

# %% [markdown]
# ### Exploring the data (`input.nc`)
#
# Before running IGM, it's useful to explore the input data file. The `input.nc` file is a NetCDF file that contains all the necessary spatial data for the glacier simulation, such as the bed topography, initial ice thickness, and other geographic information.
#
# We can use the `xarray` library to easily load and explore NetCDF files. Let's look at what's inside the `input.nc` file:

# %%
import xarray as xr
import matplotlib.pyplot as plt

# Load the NetCDF file
ds = xr.open_dataset('data/input-aletsch.nc')

# Display the dataset structure
print("Dataset structure:")
print(ds)
print("\n" + "="*60 + "\n")

# Show data variables
print("Data variables:")
for var in ds.data_vars:
    print(f"  - {var}: {ds[var].attrs.get('long_name', 'No description')}")
    print(f"    Shape: {ds[var].shape}, Units: {ds[var].attrs.get('units', 'N/A')}")
print("\n" + "="*60 + "\n")
# Out:
# Dataset structure:
# <xarray.Dataset> Size: 526kB
# Dimensions:  (y: 244, x: 179)
# Coordinates:
#   * y        (y) float32 976B 5.136e+06 5.136e+06 ... 5.16e+06 5.16e+06
#   * x        (x) float32 716B 4.15e+05 4.151e+05 ... 4.327e+05 4.328e+05
# Data variables:
#     usurf    (y, x) float32 175kB ...
#     thk      (y, x) float32 175kB ...
#     icemask  (y, x) float32 175kB ...
#
# ============================================================
#
# Data variables:
#   - usurf: Surface Topography
#     Shape: (244, 179), Units: m
#   - thk: Ice Thickness
#     Shape: (244, 179), Units: m
#   - icemask: Ice mask
#     Shape: (244, 179), Units: no unit
#
# ============================================================

# %% [markdown]
# Now let's visualize some of the key fields in the input data:

# %%
# Create a figure with multiple subplots to visualize the data
fig, axes = plt.subplots(1, 3, figsize=(14, 5))

# Plot bed topography (topg)
ds['usurf'].plot(ax=axes[0], cmap='terrain')
axes[0].set_title('Surface Topography')
axes[0].set_aspect('equal')

# Plot ice thickness (thk)
ds['thk'].plot(ax=axes[1], cmap='Blues')
axes[1].set_title('Ice Thickness')
axes[1].set_aspect('equal')

# Plot ice mask
ds['icemask'].plot(ax=axes[2], cmap='gray')
axes[2].set_title('Ice Mask')
axes[2].set_aspect('equal')

plt.tight_layout()
plt.show()

# %% [markdown]
# What you see above shows raster grids of top surface elevation, ice thickness, and ice mask for the Aletsch Glacier at a spatial resolution of 100 m.

# %% [markdown]
# ### 'Simple' Surface Mass Balance
#
# The snow accumulation budget (which turns into ice) at altitude and ice melt depends on precipitation and temperature. This mass balance $SMB(z)$ is commonly defined as a function of altitude and depends on different factors:
#
# - A slope that controls the mass balance gradients in both the accumulation $b_\mathrm{acc}$ and the ablation area $b_\mathrm{abl}$
# - A maximum value for accumulation $b_\mathrm{max}$
# - The altitude of the equilibrium line $z_\mathrm{ELA}$ beyond which ice accumulates and below which ice melts
#
# Mathematically, $SMB(z)$ can be expressed as a piecewise function:
#
# $$
# SMB(z) = \begin{cases}
# b_\mathrm{abl} \cdot (z - z_\mathrm{ELA}) & \text{if } z < z_\mathrm{ELA} \text{ (ablation zone)} \\
# \min(b_\mathrm{acc} \cdot (z - z_\mathrm{ELA}), b_\mathrm{max}) & \text{if } z \geq z_\mathrm{ELA} \text{ (accumulation zone)}
# \end{cases}
# $$
#
# The code in the next block gives an example of SMB function as a function of elevation $z$.

# %%
import numpy as np
import matplotlib.pyplot as plt

z_ELA=3000.0
grad_abl=0.009
grad_acc=0.005
b_max=2.0

def smb_fct(elev):
    smb = elev - z_ELA
    smb *= np.where(smb < 0, grad_abl, grad_acc)
    return np.minimum(smb, b_max)

elev = np.arange(2000.0, 4000.0, 20.0)
plt.axhline(y=z_ELA, color='r', linestyle='--', label='ELA')
plt.plot(smb_fct(elev), elev)
plt.ylabel('Altitude [m]')
plt.xlabel('SMB [m/y]')
plt.title('Example of SMB as a function of elevation')
plt.legend()
plt.grid(True, alpha=0.3)
plt.show()

# %% [markdown]
# ### Running IGM (`params_0`)
#
# Now, we can run IGM by simply running the command `igm_run +experiment=params_0` (or replace `params_0` with the actual name of your parameter file) in the corresponding folder to execute the example. This will model the evolution of Aletsch Glacier for 100 years given the Surface Mass Balance parameters specified in the parameter file.

# %%
# !igm_run +experiment=params_0
# Out:
# 2025-10-29 08:54:14.347950: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:485] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2025-10-29 08:54:14.383472: E external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:8454] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2025-10-29 08:54:14.394575: E external/local_xla/xla/stream_executor/cuda/cuda_blas.cc:1452] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2025-10-29 08:54:14.430537: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2025-10-29 08:54:16.908006: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# I0000 00:00:1761728063.112412   18915 cuda_executor.cc:1015] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# I0000 00:00:1761728063.168809   18915 cuda_executor.cc:1015] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# I0000 00:00:1761728063.169172   18915 cuda_executor.cc:1015] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# -------------------------------------------------------------------CUDA Enviroment--------------------------------------------------------------------
# {
#   "cpu_compiler": "/usr/lib/llvm-17/bin/clang",
#   "cuda_version": "12.3",
#   "cudnn_version": "8",
#   "is_cuda_build": true,
#   "is_rocm_build": false,
#   "is_tensorrt_build": true
# }
# ----------------------------------------------------------------Available GPU Devices-----------------------------------------------------------------
# I0000 00:00:1761728063.169661   18915 cuda_executor.cc:1015] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# {
#   "gpu_id": "/physical_device:GPU:0",
#   "device_type": "GPU",
#   "compute_capability": [
#     7,
#     5
#   ],
#   "device_name": "Tesla T4"
# }
# ------------------------------------------------------------------------------------------------------------------------------------------------------
# [PhysicalDevice(name='/physical_device:GPU:0', device_type='GPU')]
# I0000 00:00:1761728063.170639   18915 cuda_executor.cc:1015] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# I0000 00:00:1761728063.170931   18915 cuda_executor.cc:1015] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# I0000 00:00:1761728063.171138   18915 cuda_executor.cc:1015] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# I0000 00:00:1761728063.345788   18915 cuda_executor.cc:1015] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# I0000 00:00:1761728063.346173   18915 cuda_executor.cc:1015] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# I0000 00:00:1761728063.346401   18915 cuda_executor.cc:1015] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2025-10-29 08:54:23.346559: I tensorflow/core/common_runtime/gpu/gpu_device.cc:2021] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 13942 MB memory:  -> device: 0, name: Tesla T4, pci bus id: 0000:00:04.0, compute capability: 7.5
# 1 Physical GPUs, 1 Logical GPU
# ----------------------------------------------------------------------------------------------------
# -------------------------------------------INPUTS Modules-------------------------------------------
#  0: <module 'igm.inputs.local' from '/usr/local/lib/python3.12/dist-packages/igm/inputs/local.py'>
# -----------------------------------------PROCESSES Modules------------------------------------------
#  0: <module 'igm.processes.smb_simple' from '/usr/local/lib/python3.12/dist-packages/igm/processes/smb_simple/__init__.py'>
#  1: <module 'igm.processes.iceflow' from '/usr/local/lib/python3.12/dist-packages/igm/processes/iceflow/__init__.py'>
#  2: <module 'igm.processes.time' from '/usr/local/lib/python3.12/dist-packages/igm/processes/time/__init__.py'>
#  3: <module 'igm.processes.thk' from '/usr/local/lib/python3.12/dist-packages/igm/processes/thk/__init__.py'>
# ------------------------------------------OUTPUTS Modules-------------------------------------------
#  0: <module 'igm.outputs.local' from '/usr/local/lib/python3.12/dist-packages/igm/outputs/local.py'>
#  1: <module 'igm.outputs.plot2d' from '/usr/local/lib/python3.12/dist-packages/igm/outputs/plot2d.py'>
# ----------------------------------------------------------------------------------------------------
# Found pretrained emulator in the igm package: pinnbp_10_4_cnn_16_32_2_1_a
# /usr/local/lib/python3.12/dist-packages/keras/src/layers/activations/leaky_relu.py:41: UserWarning: Argument `alpha` is deprecated. Use `negative_slope` instead.
#   warnings.warn(
# Model: "model"
# ┏━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)        ┃ Output Shape      ┃    Param # ┃ Connected to      ┃
# ┡━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━┩
# │ input_1             │ (None, None,      │          0 │ -                 │
# │ (InputLayer)        │ None, 5)          │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d (Conv2D)     │ (None, None,      │      1,472 │ input_1[0][0]     │
# │                     │ None, 32)         │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ leaky_re_lu         │ (None, None,      │          0 │ conv2d[0][0],     │
# │ (LeakyReLU)         │ None, 32)         │            │ conv2d_1[0][0],   │
# │                     │                   │            │ conv2d_2[0][0],   │
# │                     │                   │            │ conv2d_3[0][0],   │
# │                     │                   │            │ conv2d_4[0][0],   │
# │                     │                   │            │ conv2d_5[0][0],   │
# │                     │                   │            │ conv2d_6[0][0],   │
# │                     │                   │            │ conv2d_7[0][0],   │
# │                     │                   │            │ conv2d_8[0][0],   │
# │                     │                   │            │ conv2d_9[0][0],   │
# │                     │                   │            │ conv2d_10[0][0],  │
# │                     │                   │            │ conv2d_11[0][0],  │
# │                     │                   │            │ conv2d_12[0][0],  │
# │                     │                   │            │ conv2d_13[0][0],  │
# │                     │                   │            │ conv2d_14[0][0],  │
# │                     │                   │            │ conv2d_15[0][0]   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dropout (Dropout)   │ (None, None,      │          0 │ leaky_re_lu[0][0] │
# │                     │ None, 32)         │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_1 (Conv2D)   │ (None, None,      │      9,248 │ dropout[0][0]     │
# │                     │ None, 32)         │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dropout_1 (Dropout) │ (None, None,      │          0 │ leaky_re_lu[1][0] │
# │                     │ None, 32)         │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_2 (Conv2D)   │ (None, None,      │      9,248 │ dropout_1[0][0]   │
# │                     │ None, 32)         │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dropout_2 (Dropout) │ (None, None,      │          0 │ leaky_re_lu[2][0] │
# │                     │ None, 32)         │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_3 (Conv2D)   │ (None, None,      │      9,248 │ dropout_2[0][0]   │
# │                     │ None, 32)         │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dropout_3 (Dropout) │ (None, None,      │          0 │ leaky_re_lu[3][0] │
# │                     │ None, 32)         │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_4 (Conv2D)   │ (None, None,      │      9,248 │ dropout_3[0][0]   │
# │                     │ None, 32)         │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dropout_4 (Dropout) │ (None, None,      │          0 │ leaky_re_lu[4][0] │
# │                     │ None, 32)         │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_5 (Conv2D)   │ (None, None,      │      9,248 │ dropout_4[0][0]   │
# │                     │ None, 32)         │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dropout_5 (Dropout) │ (None, None,      │          0 │ leaky_re_lu[5][0] │
# │                     │ None, 32)         │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_6 (Conv2D)   │ (None, None,      │      9,248 │ dropout_5[0][0]   │
# │                     │ None, 32)         │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dropout_6 (Dropout) │ (None, None,      │          0 │ leaky_re_lu[6][0] │
# │                     │ None, 32)         │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_7 (Conv2D)   │ (None, None,      │      9,248 │ dropout_6[0][0]   │
# │                     │ None, 32)         │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dropout_7 (Dropout) │ (None, None,      │          0 │ leaky_re_lu[7][0] │
# │                     │ None, 32)         │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_8 (Conv2D)   │ (None, None,      │      9,248 │ dropout_7[0][0]   │
# │                     │ None, 32)         │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dropout_8 (Dropout) │ (None, None,      │          0 │ leaky_re_lu[8][0] │
# │                     │ None, 32)         │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_9 (Conv2D)   │ (None, None,      │      9,248 │ dropout_8[0][0]   │
# │                     │ None, 32)         │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dropout_9 (Dropout) │ (None, None,      │          0 │ leaky_re_lu[9][0] │
# │                     │ None, 32)         │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_10 (Conv2D)  │ (None, None,      │      9,248 │ dropout_9[0][0]   │
# │                     │ None, 32)         │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dropout_10          │ (None, None,      │          0 │ leaky_re_lu[10][… │
# │ (Dropout)           │ None, 32)         │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_11 (Conv2D)  │ (None, None,      │      9,248 │ dropout_10[0][0]  │
# │                     │ None, 32)         │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dropout_11          │ (None, None,      │          0 │ leaky_re_lu[11][… │
# │ (Dropout)           │ None, 32)         │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_12 (Conv2D)  │ (None, None,      │      9,248 │ dropout_11[0][0]  │
# │                     │ None, 32)         │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dropout_12          │ (None, None,      │          0 │ leaky_re_lu[12][… │
# │ (Dropout)           │ None, 32)         │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_13 (Conv2D)  │ (None, None,      │      9,248 │ dropout_12[0][0]  │
# │                     │ None, 32)         │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dropout_13          │ (None, None,      │          0 │ leaky_re_lu[13][… │
# │ (Dropout)           │ None, 32)         │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_14 (Conv2D)  │ (None, None,      │      9,248 │ dropout_13[0][0]  │
# │                     │ None, 32)         │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dropout_14          │ (None, None,      │          0 │ leaky_re_lu[14][… │
# │ (Dropout)           │ None, 32)         │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_15 (Conv2D)  │ (None, None,      │      9,248 │ dropout_14[0][0]  │
# │                     │ None, 32)         │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dropout_15          │ (None, None,      │          0 │ leaky_re_lu[15][… │
# │ (Dropout)           │ None, 32)         │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_16 (Conv2D)  │ (None, None,      │        660 │ dropout_15[0][0]  │
# │                     │ None, 20)         │            │                   │
# └─────────────────────┴───────────────────┴────────────┴───────────────────┘
#  Total params: 140,852 (550.20 KB)
#  Trainable params: 140,852 (550.20 KB)
#  Non-trainable params: 0 (0.00 B)
# None
# 2025-10-29 08:54:25.258435: I external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:531] Loaded cuDNN version 8907
# W0000 00:00:1761728065.331318   18915 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1761728065.375250   18915 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1761728065.376885   18915 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1761728065.378098   18915 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1761728065.379317   18915 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1761728065.380526   18915 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1761728065.381802   18915 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1761728065.389043   18915 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1761728065.390344   18915 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1761728065.391617   18915 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1761728065.394544   18915 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1761728065.395886   18915 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1761728065.398819   18915 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1761728065.400223   18915 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1761728065.401699   18915 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1761728065.415923   18915 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1761728065.433857   18915 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1761728065.466601   18915 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1761728065.468044   18915 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1761728065.469563   18915 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1761728065.471086   18915 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1761728065.472619   18915 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1761728065.474154   18915 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1761728065.475742   18915 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1761728065.490808   18915 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1761728065.492537   18915 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1761728065.494289   18915 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1761728065.496137   18915 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1761728065.497940   18915 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1761728065.499829   18915 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1761728065.502141   18915 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1761728065.504450   18915 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1761728065.507464   18915 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1761728065.511093   18915 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1761728065.533491   18915 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# /usr/local/lib/python3.12/dist-packages/tensorflow/python/framework/tensor_util.py:522: RuntimeWarning: overflow encountered in cast
#   nparray = np.array(values, dtype=np_dt)
# W0000 00:00:1761728072.836851   18915 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1761728072.838363   18915 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1761728072.840374   18915 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1761728072.850488   18915 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1761728072.852923   18915 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1761728072.855390   18915 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1761728072.857796   18915 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1761728072.860283   18915 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1761728072.864004   18915 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1761728072.867615   18915 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1761728072.898694   18915 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1761728072.936189   18915 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1761728072.939351   18915 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1761728072.942637   18915 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1761728072.944725   18915 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1761728072.948889   18915 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1761728072.953479   18915 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1761728072.965687   18915 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1761728072.970678   18915 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1761728072.973985   18915 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1761728072.976570   18915 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1761728072.980776   18915 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1761728072.985052   18915 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1761728072.991085   18915 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1761728073.026247   18915 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1761728073.027967   18915 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1761728073.029398   18915 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1761728073.031179   18915 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1761728073.032259   18915 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1761728073.033341   18915 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1761728073.034409   18915 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1761728073.036426   18915 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1761728073.038355   18915 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1761728073.039779   18915 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1761728073.044926   18915 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1761728073.046019   18915 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1761728073.047095   18915 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1761728073.048639   18915 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1761728073.050105   18915 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1761728073.051378   18915 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1761728073.052849   18915 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1761728073.054552   18915 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1761728073.056839   18915 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1761728073.059079   18915 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1761728073.060792   18915 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1761728073.063437   18915 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# IGM , 🕒=08:54:45, 🔄=000100, ⏱ Time=0001926.5 yr, ⏳ Step=0.20 yr, ❄️  Volume=14.17 km³
# IGM , 🕒=08:54:54, 🔄=000200, ⏱ Time=0001944.5 yr, ⏳ Step=0.21 yr, ❄️  Volume=14.68 km³
# IGM , 🕒=08:55:04, 🔄=000300, ⏱ Time=0001963.2 yr, ⏳ Step=0.16 yr, ❄️  Volume=15.46 km³
# IGM , 🕒=08:55:15, 🔄=000400, ⏱ Time=0001980.6 yr, ⏳ Step=0.17 yr, ❄️  Volume=16.04 km³
# IGM , 🕒=08:55:25, 🔄=000500, ⏱ Time=0001999.0 yr, ⏳ Step=0.21 yr, ❄️  Volume=16.45 km³
# IGM , 🕒=08:55:27, 🔄=000505, ⏱ Time=0002000.0 yr, ⏳ Step=0.19 yr, ❄️  Volume=16.47 km³

# %% [markdown]
# ### Explore the output
#
# Each IGM run will generate a folder with the date as the parent folder and the time as a subfolder. For instance, after a few runs we could end up with the following structure:
#
# ```bash
# outputs
#   └───2025-04-07
#       ├─── 12-06-29
#       └─── 12-07-38
# ```

# %%
# !tree
# Out:
# .
# ├── data
# │   ├── input-aletsch.nc
# │   ├── RGI2000-v7.0-G-11-02596
# │   │   ├── climate_historical.nc
# │   │   ├── COPDEM30
# │   │   │   ├── dem_source.txt
# │   │   │   └── dem.tif
# │   │   ├── COPDEM90
# │   │   │   ├── dem_source.txt
# │   │   │   └── dem.tif
# │   │   ├── dem_source.txt
# │   │   ├── dem.tif
# │   │   ├── diagnostics.json
# │   │   ├── downstream_line.pkl
# │   │   ├── elevation_band_flowline.csv
# │   │   ├── elevation_band_flowline_fixed_dx.csv
# │   │   ├── glacier_grid.json
# │   │   ├── glacier_mask.tif
# │   │   ├── glathida_data.csv
# │   │   ├── gridded_data.nc
# │   │   ├── intersects.tar.gz
# │   │   ├── inversion_flowlines.pkl
# │   │   ├── log.txt
# │   │   ├── mb_calib.json
# │   │   ├── NASADEM
# │   │   │   ├── dem_source.txt
# │   │   │   └── dem.tif
# │   │   └── outlines.tar.gz
# │   └── RGI60-11.01450
# │       ├── climate_historical.nc
# │       ├── dem_source.txt
# │       ├── dem.tif
# │       ├── diagnostics.json
# │       ├── downstream_line.pkl
# │       ├── elevation_band_flowline.csv
# │       ├── elevation_band_flowline_fixed_dx.csv
# │       ├── glacier_grid.json
# │       ├── gridded_data.nc
# │       ├── intersects.tar.gz
# │       ├── inversion_flowlines.pkl
# │       ├── inversion_input.pkl
# │       ├── inversion_output.pkl
# │       ├── log.txt
# │       ├── mb_calib.json
# │       ├── model_flowlines.pkl
# │       └── outlines.tar.gz
# ├── experiment
# │   ├── params_0.yaml
# │   ├── params_1.yaml
# │   ├── params_29oct.yaml
# │   └── params_2.yaml
# ├── glacier-modelling-29oct.ipynb
# ├── glacier-modelling-2.ipynb
# ├── glamod
# │   ├── 00_introduction
# │   │   ├── 00_introduction.md
# │   │   └── fig
# │   │       ├── AIF-CH.png
# │   │       ├── AIF-leger-lq.png
# │   │       ├── AIF-lq.png
# │   │       ├── AIF.png
# │   │       ├── aletsch.jpg
# │   │       ├── algo.gif
# │   │       ├── argen1.JPG
# │   │       ├── climbers2.jpg
# │   │       ├── cordonnier_lq.png
# │   │       ├── course_illu.png
# │   │       ├── Figure7.png
# │   │       ├── glacier-goo.png
# │   │       ├── gl-equations.png
# │   │       ├── gletsch-1856.jpg
# │   │       ├── leger2024-lq.png
# │   │       ├── leger2024.png
# │   │       ├── LGM-cities.jpg
# │   │       ├── mercanton.jpg
# │   │       ├── MESH.png
# │   │       ├── pic1.jpg
# │   │       ├── pic2.jpg
# │   │       ├── rhone-mod-lq.png
# │   │       ├── rhone-mod.png
# │   │       ├── rhone-mod-short.png
# │   │       ├── scheme_glacier.png
# │   │       ├── scheme-ice-shelf.png
# │   │       ├── scheme.png
# │   │       ├── shearing-sliding.png
# │   │       ├── SIA-profile.png
# │   │       ├── sia-vs-ssa.png
# │   │       ├── simple_glacierA.png
# │   │       ├── stress-strain-BuddJacka1989.png
# │   │       ├── till.png
# │   │       └── velocity-smb-rhone.png
# │   ├── 00_project
# │   │   └── project.md
# │   ├── 01_notebook
# │   │   ├── glacier-modelling-1.ipynb
# │   │   └── topg.txt
# │   ├── 02_notebook
# │   │   ├── data
# │   │   │   └── input-aletsch.nc
# │   │   ├── experiment
# │   │   │   ├── params_0.yaml
# │   │   │   ├── params_1.yaml
# │   │   │   ├── params_29oct.yaml
# │   │   │   └── params_2.yaml
# │   │   ├── glacier-modelling-2.ipynb
# │   │   ├── helper.py
# │   │   └── user
# │   │       ├── code
# │   │       │   └── processes
# │   │       │       └── mysmb.py
# │   │       └── conf
# │   │           └── processes
# │   │               └── mysmb.yaml
# │   ├── 0-clean.sh
# │   ├── 1-build-site.sh
# │   ├── 2-check-site.sh
# │   ├── 3-publish-site.sh
# │   ├── _config.yml
# │   ├── infos.md
# │   ├── _toc.yml
# │   └── zip-exercices.sh
# ├── helper.py
# ├── outputs
# │   └── 2025-10-29
# │       ├── 07-54-32
# │       │   ├── igm_run.log
# │       │   ├── output.nc
# │       │   ├── output_ts.nc
# │       │   ├── velbar_mag-1900.0.png
# │       │   ├── velbar_mag-1910.0.png
# │       │   ├── velbar_mag-1920.0.png
# │       │   ├── velbar_mag-1930.0.png
# │       │   ├── velbar_mag-1940.0.png
# │       │   ├── velbar_mag-1950.0.png
# │       │   ├── velbar_mag-1960.0.png
# │       │   ├── velbar_mag-1970.0.png
# │       │   ├── velbar_mag-1980.0.png
# │       │   ├── velbar_mag-1990.0.png
# │       │   └── velbar_mag-2000.0.png
# │       ├── 07-55-48
# │       │   ├── igm_run.log
# │       │   ├── output.nc
# │       │   ├── output_ts.nc
# │       │   ├── velbar_mag-1800.0.png
# │       │   ├── velbar_mag-1810.0.png
# │       │   ├── velbar_mag-1820.0.png
# │       │   ├── velbar_mag-1830.0.png
# │       │   ├── velbar_mag-1840.0.png
# │       │   ├── velbar_mag-1850.0.png
# │       │   ├── velbar_mag-1860.0.png
# │       │   ├── velbar_mag-1870.0.png
# │       │   ├── velbar_mag-1880.0.png
# │       │   ├── velbar_mag-1890.0.png
# │       │   ├── velbar_mag-1900.0.png
# │       │   ├── velbar_mag-1910.0.png
# │       │   ├── velbar_mag-1920.0.png
# │       │   ├── velbar_mag-1930.0.png
# │       │   ├── velbar_mag-1940.0.png
# │       │   ├── velbar_mag-1950.0.png
# │       │   ├── velbar_mag-1960.0.png
# │       │   ├── velbar_mag-1970.0.png
# │       │   ├── velbar_mag-1980.0.png
# │       │   ├── velbar_mag-1990.0.png
# │       │   ├── velbar_mag-2000.0.png
# │       │   ├── velbar_mag-2010.0.png
# │       │   ├── velbar_mag-2020.0.png
# │       │   ├── velbar_mag-2030.0.png
# │       │   ├── velbar_mag-2040.0.png
# │       │   ├── velbar_mag-2050.0.png
# │       │   ├── velbar_mag-2060.0.png
# │       │   ├── velbar_mag-2070.0.png
# │       │   ├── velbar_mag-2080.0.png
# │       │   ├── velbar_mag-2090.0.png
# │       │   └── velbar_mag-2100.0.png
# │       ├── 08-01-24
# │       │   ├── igm_run.log
# │       │   ├── output.nc
# │       │   ├── output_ts.nc
# │       │   ├── trajectories
# │       │   │   ├── time.dat
# │       │   │   ├── topg.csv
# │       │   │   ├── traj-02000-00.csv
# │       │   │   ├── traj-02010-00.csv
# │       │   │   ├── traj-02020-00.csv
# │       │   │   ├── traj-02030-00.csv
# │       │   │   ├── traj-02040-00.csv
# │       │   │   ├── traj-02050-00.csv
# │       │   │   ├── traj-02060-00.csv
# │       │   │   ├── traj-02070-00.csv
# │       │   │   ├── traj-02080-00.csv
# │       │   │   ├── traj-02090-00.csv
# │       │   │   ├── traj-02100-00.csv
# │       │   │   ├── usurf-02000-00.csv
# │       │   │   ├── usurf-02010-00.csv
# │       │   │   ├── usurf-02020-00.csv
# │       │   │   ├── usurf-02030-00.csv
# │       │   │   ├── usurf-02040-00.csv
# │       │   │   ├── usurf-02050-00.csv
# │       │   │   ├── usurf-02060-00.csv
# │       │   │   ├── usurf-02070-00.csv
# │       │   │   ├── usurf-02080-00.csv
# │       │   │   ├── usurf-02090-00.csv
# │       │   │   └── usurf-02100-00.csv
# │       │   ├── velbar_mag-2000.0.png
# │       │   ├── velbar_mag-2010.0.png
# │       │   ├── velbar_mag-2020.0.png
# │       │   ├── velbar_mag-2030.0.png
# │       │   ├── velbar_mag-2040.0.png
# │       │   ├── velbar_mag-2050.0.png
# │       │   ├── velbar_mag-2060.0.png
# │       │   ├── velbar_mag-2070.0.png
# │       │   ├── velbar_mag-2080.0.png
# │       │   ├── velbar_mag-2090.0.png
# │       │   └── velbar_mag-2100.0.png
# │       └── 08-54-22
# │           ├── igm_run.log
# │           ├── output.nc
# │           ├── output_ts.nc
# │           ├── velbar_mag-1900.0.png
# │           ├── velbar_mag-1910.0.png
# │           ├── velbar_mag-1920.0.png
# │           ├── velbar_mag-1930.0.png
# │           ├── velbar_mag-1940.0.png
# │           ├── velbar_mag-1950.0.png
# │           ├── velbar_mag-1960.0.png
# │           ├── velbar_mag-1970.0.png
# │           ├── velbar_mag-1980.0.png
# │           ├── velbar_mag-1990.0.png
# │           └── velbar_mag-2000.0.png
# ├── __pycache__
# │   └── helper.cpython-312.pyc
# └── user
#     ├── code
#     │   └── processes
#     │       ├── mysmb.py
#     │       └── __pycache__
#     │           └── mysmb.cpython-312.pyc
#     └── conf
#         └── processes
#             └── mysmb.yaml
#
# 34 directories, 206 files

# %% [markdown]
# After the IGM run, you may have a quick look at the results by exploring:
#
# - Files `velbar_mag-19XX.0.png` that display ice speed and extent over the simulation time
# - `output.nc` that stores all the spatio-temporal output results
# - `output_ts.nc` that stores all time-dependent volume and area data
#
# Using the helper function, you can visualize the results:

# %%
from helper import *
import glob

# Find all output files
A = glob.glob('outputs/*/*/output.nc')
print(f"Found {len(A)} output file(s):", A)

if A:
    # Animate the last run
    animate_glacier_evolution(A[-1])
else:
    print("No output.nc files found. Please run the model first.")
# Out:
# Found 4 output file(s): ['outputs/2025-10-29/07-55-48/output.nc', 'outputs/2025-10-29/07-54-32/output.nc', 'outputs/2025-10-29/08-01-24/output.nc', 'outputs/2025-10-29/08-54-22/output.nc']

# %% [markdown]
# ### Analyzing the time series results
#
# Let's examine how the glacier ice volume and ice area evolved over the simulation period by reading the `output_ts.nc` file:

# %%
from helper import *
import glob
import os

# Find all time series files and select the most recent one
ts_files = sorted(glob.glob('outputs/*/*/output_ts.nc'))

if ts_files:
    # Get the absolute path to ensure it works from any directory
    ts_file = os.path.abspath(ts_files[-1])
    print(f"Found {len(ts_files)} time series file(s). Using: {ts_files[-1]}\n")
    # Analyze the time series from the most recent run
    analyze_time_series(ts_file)
else:
    print("No output_ts.nc file found. Please run the model first.")
# Out:
# Found 4 time series file(s). Using: outputs/2025-10-29/08-54-22/output_ts.nc
#
# Reading time series data from: /content/glamod/02_notebook/outputs/2025-10-29/08-54-22/output_ts.nc
# ============================================================
# SUMMARY STATISTICS
# ============================================================
#
# Ice Volume:
#   Initial: 13.75 km³
#   Final:   16.47 km³
#   Change:  2.71 km³
#
# Ice Area:
#   Initial: 84.35 km²
#   Final:   82.03 km²
#   Change:  -2.32 km²
# ============================================================

# %% [markdown]
# Congratulations! You have successfully run your first glacier model simulation using the IGM package. You can now explore different parameters and scenarios to see how they affect glacier dynamics. Happy modeling!
#
# You may now try to modify some parameters in the configuration file `params_0.yaml` and rerun the simulation to observe how changes impact the glacier's behavior.
#
# **Tips:** Create a new parameter file by copying `params_0.yaml` to `params_0_student.yaml` and modify it. Then run the simulation with the command `igm_run +experiment=params_0_student`.

# %% [markdown]
# ## Second run with IGM

# %% [markdown]
# The above example is somewhat limited. In a second run, we are making improvements using `params_1.yaml` instead of `params_0.yaml`:
#
# **First improvement:** Instead of using local data, we use the module `oggm_shop` to download all necessary data. The main advantage is that we can order any glacier using their RGI ID, and therefore get the data for any glacier on Earth!
#
# **Second improvement:** OGGM will download climate data (a time series), which will serve to generate a climate (temperature and precipitation in module `clim_oggm`) to compute a better Surface Mass Balance model. Note this parameter in the parameter file:
#
# ```yaml
#   clim_oggm:
#     clim_trend_array:
#       - ["time", "delta_temp", "prec_scal"]
#       - [ 1900,           0.0,         1.0]
#       - [ 2020,           0.0,         1.0]
#       - [ 2100,           4.0,         1.0]
# ```
#
# Similar to the previous method, this array assigns weights to modify precipitation and temperature series based on a *neutral* climate period, typically defined as 1960-1990. By adjusting the temperature offset in the `delta_temp` column, for example, a value of -2.0 would create a climate scenario for the 1960-1990 period that is 2 degrees cooler. Likewise, by modifying the precipitation scaling in the `prec_scal` column, a value of 1.5 would result in a climate scenario that has 150% of the precipitation compared to the 1960-1990 average.
#
# Finally, you can incorporate this parameter to provide global control for melt (note that the melt parameters in the PDD model are notoriously uncertain):
#
# ```yaml
#    melt_enhancer: 0.7
# ```
#
# Find more information about the generated climate [here](https://igm-model.org/latest/modules/processes/clim_oggm/).
#
# **Third improvement:** Instead of using the Simple Surface Mass Balance `smb_simple`, and now that we have climate available, we will use the `smb_oggm` SMB, which is a monthly temperature index model as described [here](https://igm-model.org/latest/modules/processes/smb_oggm/).
#
# First explore `params_1.yaml`, then run the following command, which will model the Glacier with RGI ID `RGI60-11.01450` (the Great Aletsch Glacier, Switzerland) from 2020 to 2100, assuming a temperature increase of 4 degrees by 2100 relative to 1960–1990:

# %%
! igm_run +experiment=params_1
# Out:
# 2025-10-29 08:55:32.422163: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:485] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2025-10-29 08:55:32.441862: E external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:8454] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2025-10-29 08:55:32.447973: E external/local_xla/xla/stream_executor/cuda/cuda_blas.cc:1452] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2025-10-29 08:55:32.462413: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2025-10-29 08:55:33.972306: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# I0000 00:00:1761728137.428708   19360 cuda_executor.cc:1015] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# I0000 00:00:1761728137.474023   19360 cuda_executor.cc:1015] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# I0000 00:00:1761728137.474365   19360 cuda_executor.cc:1015] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# -------------------------------------------------------------------CUDA Enviroment--------------------------------------------------------------------
# {
#   "cpu_compiler": "/usr/lib/llvm-17/bin/clang",
#   "cuda_version": "12.3",
#   "cudnn_version": "8",
#   "is_cuda_build": true,
#   "is_rocm_build": false,
#   "is_tensorrt_build": true
# }
# ----------------------------------------------------------------Available GPU Devices-----------------------------------------------------------------
# I0000 00:00:1761728137.474888   19360 cuda_executor.cc:1015] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# {
#   "gpu_id": "/physical_device:GPU:0",
#   "device_type": "GPU",
#   "compute_capability": [
#     7,
#     5
#   ],
#   "device_name": "Tesla T4"
# }
# ------------------------------------------------------------------------------------------------------------------------------------------------------
# [PhysicalDevice(name='/physical_device:GPU:0', device_type='GPU')]
# I0000 00:00:1761728137.475911   19360 cuda_executor.cc:1015] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# I0000 00:00:1761728137.476159   19360 cuda_executor.cc:1015] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# I0000 00:00:1761728137.476360   19360 cuda_executor.cc:1015] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# I0000 00:00:1761728137.660951   19360 cuda_executor.cc:1015] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# I0000 00:00:1761728137.661342   19360 cuda_executor.cc:1015] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# I0000 00:00:1761728137.661578   19360 cuda_executor.cc:1015] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2025-10-29 08:55:37.661728: I tensorflow/core/common_runtime/gpu/gpu_device.cc:2021] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 13942 MB memory:  -> device: 0, name: Tesla T4, pci bus id: 0000:00:04.0, compute capability: 7.5
# 1 Physical GPUs, 1 Logical GPU
# ----------------------------------------------------------------------------------------------------
# -------------------------------------------INPUTS Modules-------------------------------------------
#  0: <module 'igm.inputs.oggm_shop' from '/usr/local/lib/python3.12/dist-packages/igm/inputs/oggm_shop/__init__.py'>
#  1: <module 'igm.inputs.local' from '/usr/local/lib/python3.12/dist-packages/igm/inputs/local.py'>
# -----------------------------------------PROCESSES Modules------------------------------------------
#  0: <module 'igm.processes.clim_oggm' from '/usr/local/lib/python3.12/dist-packages/igm/processes/clim_oggm/__init__.py'>
#  1: <module 'igm.processes.smb_oggm' from '/usr/local/lib/python3.12/dist-packages/igm/processes/smb_oggm/__init__.py'>
#  2: <module 'igm.processes.iceflow' from '/usr/local/lib/python3.12/dist-packages/igm/processes/iceflow/__init__.py'>
#  3: <module 'igm.processes.time' from '/usr/local/lib/python3.12/dist-packages/igm/processes/time/__init__.py'>
#  4: <module 'igm.processes.thk' from '/usr/local/lib/python3.12/dist-packages/igm/processes/thk/__init__.py'>
# ------------------------------------------OUTPUTS Modules-------------------------------------------
#  0: <module 'igm.outputs.local' from '/usr/local/lib/python3.12/dist-packages/igm/outputs/local.py'>
#  1: <module 'igm.outputs.plot2d' from '/usr/local/lib/python3.12/dist-packages/igm/outputs/plot2d.py'>
# ----------------------------------------------------------------------------------------------------
# 2025-10-29 08:55:37: oggm.cfg: Reading default parameters from the OGGM `params.cfg` configuration file.
# 2025-10-29 08:55:37: oggm.cfg: Multiprocessing switched OFF according to the parameter file.
# 2025-10-29 08:55:37: oggm.cfg: Multiprocessing: using all available processors (N=2)
# 2025-10-29 08:55:37: oggm.cfg: PARAMS['continue_on_error'] changed from `False` to `True`.
# 2025-10-29 08:55:38: oggm.workflow: init_glacier_directories from prepro level 3 on 1 glaciers.
# 2025-10-29 08:55:38: oggm.workflow: Execute entity tasks [gdir_from_prepro] on 1 glaciers
# Found pretrained emulator in the igm package: pinnbp_10_4_cnn_16_32_2_1_a
# /usr/local/lib/python3.12/dist-packages/keras/src/layers/activations/leaky_relu.py:41: UserWarning: Argument `alpha` is deprecated. Use `negative_slope` instead.
#   warnings.warn(
# Model: "model"
# ┏━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)        ┃ Output Shape      ┃    Param # ┃ Connected to      ┃
# ┡━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━┩
# │ input_1             │ (None, None,      │          0 │ -                 │
# │ (InputLayer)        │ None, 5)          │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d (Conv2D)     │ (None, None,      │      1,472 │ input_1[0][0]     │
# │                     │ None, 32)         │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ leaky_re_lu         │ (None, None,      │          0 │ conv2d[0][0],     │
# │ (LeakyReLU)         │ None, 32)         │            │ conv2d_1[0][0],   │
# │                     │                   │            │ conv2d_2[0][0],   │
# │                     │                   │            │ conv2d_3[0][0],   │
# │                     │                   │            │ conv2d_4[0][0],   │
# │                     │                   │            │ conv2d_5[0][0],   │
# │                     │                   │            │ conv2d_6[0][0],   │
# │                     │                   │            │ conv2d_7[0][0],   │
# │                     │                   │            │ conv2d_8[0][0],   │
# │                     │                   │            │ conv2d_9[0][0],   │
# │                     │                   │            │ conv2d_10[0][0],  │
# │                     │                   │            │ conv2d_11[0][0],  │
# │                     │                   │            │ conv2d_12[0][0],  │
# │                     │                   │            │ conv2d_13[0][0],  │
# │                     │                   │            │ conv2d_14[0][0],  │
# │                     │                   │            │ conv2d_15[0][0]   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dropout (Dropout)   │ (None, None,      │          0 │ leaky_re_lu[0][0] │
# │                     │ None, 32)         │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_1 (Conv2D)   │ (None, None,      │      9,248 │ dropout[0][0]     │
# │                     │ None, 32)         │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dropout_1 (Dropout) │ (None, None,      │          0 │ leaky_re_lu[1][0] │
# │                     │ None, 32)         │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_2 (Conv2D)   │ (None, None,      │      9,248 │ dropout_1[0][0]   │
# │                     │ None, 32)         │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dropout_2 (Dropout) │ (None, None,      │          0 │ leaky_re_lu[2][0] │
# │                     │ None, 32)         │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_3 (Conv2D)   │ (None, None,      │      9,248 │ dropout_2[0][0]   │
# │                     │ None, 32)         │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dropout_3 (Dropout) │ (None, None,      │          0 │ leaky_re_lu[3][0] │
# │                     │ None, 32)         │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_4 (Conv2D)   │ (None, None,      │      9,248 │ dropout_3[0][0]   │
# │                     │ None, 32)         │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dropout_4 (Dropout) │ (None, None,      │          0 │ leaky_re_lu[4][0] │
# │                     │ None, 32)         │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_5 (Conv2D)   │ (None, None,      │      9,248 │ dropout_4[0][0]   │
# │                     │ None, 32)         │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dropout_5 (Dropout) │ (None, None,      │          0 │ leaky_re_lu[5][0] │
# │                     │ None, 32)         │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_6 (Conv2D)   │ (None, None,      │      9,248 │ dropout_5[0][0]   │
# │                     │ None, 32)         │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dropout_6 (Dropout) │ (None, None,      │          0 │ leaky_re_lu[6][0] │
# │                     │ None, 32)         │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_7 (Conv2D)   │ (None, None,      │      9,248 │ dropout_6[0][0]   │
# │                     │ None, 32)         │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dropout_7 (Dropout) │ (None, None,      │          0 │ leaky_re_lu[7][0] │
# │                     │ None, 32)         │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_8 (Conv2D)   │ (None, None,      │      9,248 │ dropout_7[0][0]   │
# │                     │ None, 32)         │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dropout_8 (Dropout) │ (None, None,      │          0 │ leaky_re_lu[8][0] │
# │                     │ None, 32)         │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_9 (Conv2D)   │ (None, None,      │      9,248 │ dropout_8[0][0]   │
# │                     │ None, 32)         │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dropout_9 (Dropout) │ (None, None,      │          0 │ leaky_re_lu[9][0] │
# │                     │ None, 32)         │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_10 (Conv2D)  │ (None, None,      │      9,248 │ dropout_9[0][0]   │
# │                     │ None, 32)         │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dropout_10          │ (None, None,      │          0 │ leaky_re_lu[10][… │
# │ (Dropout)           │ None, 32)         │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_11 (Conv2D)  │ (None, None,      │      9,248 │ dropout_10[0][0]  │
# │                     │ None, 32)         │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dropout_11          │ (None, None,      │          0 │ leaky_re_lu[11][… │
# │ (Dropout)           │ None, 32)         │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_12 (Conv2D)  │ (None, None,      │      9,248 │ dropout_11[0][0]  │
# │                     │ None, 32)         │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dropout_12          │ (None, None,      │          0 │ leaky_re_lu[12][… │
# │ (Dropout)           │ None, 32)         │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_13 (Conv2D)  │ (None, None,      │      9,248 │ dropout_12[0][0]  │
# │                     │ None, 32)         │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dropout_13          │ (None, None,      │          0 │ leaky_re_lu[13][… │
# │ (Dropout)           │ None, 32)         │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_14 (Conv2D)  │ (None, None,      │      9,248 │ dropout_13[0][0]  │
# │                     │ None, 32)         │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dropout_14          │ (None, None,      │          0 │ leaky_re_lu[14][… │
# │ (Dropout)           │ None, 32)         │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_15 (Conv2D)  │ (None, None,      │      9,248 │ dropout_14[0][0]  │
# │                     │ None, 32)         │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dropout_15          │ (None, None,      │          0 │ leaky_re_lu[15][… │
# │ (Dropout)           │ None, 32)         │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_16 (Conv2D)  │ (None, None,      │        660 │ dropout_15[0][0]  │
# │                     │ None, 20)         │            │                   │
# └─────────────────────┴───────────────────┴────────────┴───────────────────┘
#  Total params: 140,852 (550.20 KB)
#  Trainable params: 140,852 (550.20 KB)
#  Non-trainable params: 0 (0.00 B)
# None
# 2025-10-29 08:55:41.287020: I external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:531] Loaded cuDNN version 8907
# W0000 00:00:1761728141.364718   19360 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1761728141.407210   19360 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1761728141.408817   19360 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1761728141.410017   19360 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1761728141.411228   19360 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1761728141.412432   19360 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1761728141.413726   19360 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1761728141.419722   19360 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1761728141.421042   19360 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1761728141.422316   19360 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1761728141.425159   19360 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1761728141.426480   19360 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1761728141.429333   19360 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1761728141.430745   19360 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1761728141.432229   19360 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1761728141.446422   19360 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1761728141.463640   19360 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1761728141.496261   19360 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1761728141.497712   19360 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1761728141.499246   19360 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1761728141.500790   19360 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1761728141.502318   19360 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1761728141.503848   19360 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1761728141.505415   19360 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1761728141.519174   19360 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1761728141.520967   19360 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1761728141.522714   19360 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1761728141.524532   19360 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1761728141.526334   19360 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1761728141.528176   19360 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1761728141.530485   19360 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1761728141.532801   19360 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1761728141.535699   19360 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1761728141.539382   19360 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1761728141.560018   19360 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# /usr/local/lib/python3.12/dist-packages/tensorflow/python/framework/tensor_util.py:522: RuntimeWarning: overflow encountered in cast
#   nparray = np.array(values, dtype=np_dt)
# W0000 00:00:1761728149.842126   19360 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1761728149.843608   19360 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1761728149.845451   19360 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1761728149.853687   19360 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1761728149.856125   19360 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1761728149.858635   19360 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1761728149.861148   19360 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1761728149.863625   19360 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1761728149.867404   19360 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1761728149.871081   19360 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1761728149.894201   19360 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1761728149.923989   19360 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1761728149.926813   19360 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1761728149.929646   19360 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1761728149.931758   19360 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1761728149.935395   19360 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1761728149.939594   19360 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1761728149.943822   19360 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1761728149.946204   19360 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1761728149.949462   19360 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1761728149.953656   19360 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1761728149.957789   19360 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1761728149.963819   19360 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1761728149.976014   19360 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1761728150.004011   19360 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1761728150.012330   19360 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1761728150.014092   19360 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1761728150.016402   19360 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1761728150.017745   19360 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1761728150.019065   19360 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1761728150.020379   19360 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1761728150.023053   19360 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1761728150.025609   19360 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1761728150.027394   19360 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1761728150.032645   19360 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1761728150.033989   19360 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1761728150.035301   19360 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1761728150.037209   19360 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1761728150.039019   19360 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1761728150.040637   19360 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1761728150.042574   19360 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1761728150.044840   19360 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1761728150.047628   19360 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1761728150.050571   19360 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1761728150.052796   19360 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1761728150.056413   19360 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# IGM , 🕒=08:56:01, 🔄=000100, ⏱ Time=0001819.3 yr, ⏳ Step=0.13 yr, ❄️  Volume=1.36 km³
# IGM , 🕒=08:56:10, 🔄=000200, ⏱ Time=0001829.2 yr, ⏳ Step=0.08 yr, ❄️  Volume=1.49 km³
# IGM , 🕒=08:56:19, 🔄=000300, ⏱ Time=0001837.1 yr, ⏳ Step=0.08 yr, ❄️  Volume=1.58 km³
# IGM , 🕒=08:56:28, 🔄=000400, ⏱ Time=0001845.4 yr, ⏳ Step=0.09 yr, ❄️  Volume=1.67 km³
# IGM , 🕒=08:56:37, 🔄=000500, ⏱ Time=0001854.9 yr, ⏳ Step=0.10 yr, ❄️  Volume=1.72 km³
# IGM , 🕒=08:56:47, 🔄=000600, ⏱ Time=0001864.0 yr, ⏳ Step=0.09 yr, ❄️  Volume=1.85 km³
# IGM , 🕒=08:56:56, 🔄=000700, ⏱ Time=0001873.5 yr, ⏳ Step=0.10 yr, ❄️  Volume=1.89 km³
# IGM , 🕒=08:57:06, 🔄=000800, ⏱ Time=0001883.2 yr, ⏳ Step=0.10 yr, ❄️  Volume=1.97 km³
# IGM , 🕒=08:57:16, 🔄=000900, ⏱ Time=0001892.9 yr, ⏳ Step=0.10 yr, ❄️  Volume=1.99 km³
# IGM , 🕒=08:57:26, 🔄=001000, ⏱ Time=0001902.9 yr, ⏳ Step=0.09 yr, ❄️  Volume=2.11 km³
# IGM , 🕒=08:57:37, 🔄=001100, ⏱ Time=0001912.3 yr, ⏳ Step=0.10 yr, ❄️  Volume=2.15 km³
# IGM , 🕒=08:57:47, 🔄=001200, ⏱ Time=0001921.8 yr, ⏳ Step=0.10 yr, ❄️  Volume=2.25 km³
# IGM , 🕒=08:57:57, 🔄=001300, ⏱ Time=0001931.6 yr, ⏳ Step=0.10 yr, ❄️  Volume=2.28 km³
# IGM , 🕒=08:58:08, 🔄=001400, ⏱ Time=0001941.7 yr, ⏳ Step=0.10 yr, ❄️  Volume=2.33 km³
# IGM , 🕒=08:58:19, 🔄=001500, ⏱ Time=0001952.2 yr, ⏳ Step=0.11 yr, ❄️  Volume=2.21 km³
# IGM , 🕒=08:58:30, 🔄=001600, ⏱ Time=0001962.9 yr, ⏳ Step=0.10 yr, ❄️  Volume=2.21 km³
# IGM , 🕒=08:58:41, 🔄=001700, ⏱ Time=0001972.8 yr, ⏳ Step=0.10 yr, ❄️  Volume=2.25 km³
# IGM , 🕒=08:58:53, 🔄=001800, ⏱ Time=0001982.6 yr, ⏳ Step=0.10 yr, ❄️  Volume=2.33 km³
# IGM , 🕒=08:59:05, 🔄=001900, ⏱ Time=0001992.5 yr, ⏳ Step=0.11 yr, ❄️  Volume=2.26 km³
# IGM , 🕒=08:59:17, 🔄=002000, ⏱ Time=0002003.5 yr, ⏳ Step=0.11 yr, ❄️  Volume=2.15 km³
# IGM , 🕒=08:59:29, 🔄=002100, ⏱ Time=0002015.3 yr, ⏳ Step=0.12 yr, ❄️  Volume=1.94 km³
# IGM , 🕒=08:59:41, 🔄=002200, ⏱ Time=0002026.6 yr, ⏳ Step=0.10 yr, ❄️  Volume=1.93 km³
# IGM , 🕒=08:59:53, 🔄=002300, ⏱ Time=0002036.0 yr, ⏳ Step=0.10 yr, ❄️  Volume=1.95 km³
# IGM , 🕒=09:00:06, 🔄=002400, ⏱ Time=0002046.0 yr, ⏳ Step=0.10 yr, ❄️  Volume=1.88 km³
# IGM , 🕒=09:00:19, 🔄=002500, ⏱ Time=0002056.6 yr, ⏳ Step=0.11 yr, ❄️  Volume=1.76 km³
# IGM , 🕒=09:00:32, 🔄=002600, ⏱ Time=0002068.3 yr, ⏳ Step=0.12 yr, ❄️  Volume=1.54 km³
# IGM , 🕒=09:00:51, 🔄=002700, ⏱ Time=0002081.6 yr, ⏳ Step=0.15 yr, ❄️  Volume=1.17 km³
# IGM , 🕒=09:01:04, 🔄=002800, ⏱ Time=0002098.1 yr, ⏳ Step=0.18 yr, ❄️  Volume=0.68 km³
# IGM , 🕒=09:01:10, 🔄=002811, ⏱ Time=0002100.0 yr, ⏳ Step=0.04 yr, ❄️  Volume=0.65 km³

# %% [markdown]
# ## Visualizing Climate Data
#
# Let's explore the historical climate data that was used for the glacier simulation. We will open the `climate_historical.nc` file and plot the smoothed precipitation and temperature time series on the same graph.

# %%
import xarray as xr
import matplotlib.pyplot as plt
import numpy as np
from scipy.ndimage import uniform_filter1d

# Open the climate data
climate_data = xr.open_dataset('data/RGI2000-v7.0-G-11-02596/climate_historical.nc')

# Extract temperature and precipitation
temp = climate_data['temp'].values
prcp = climate_data['prcp'].values
time = climate_data['time'].values

# Apply smoothing (moving average with window size of 12 months for annual smoothing)
window_size = 12
temp_smoothed = uniform_filter1d(temp, size=window_size, mode='nearest')
prcp_smoothed = uniform_filter1d(prcp, size=window_size, mode='nearest')

# Create figure with two y-axes
fig, ax1 = plt.subplots(figsize=(12, 6))

# Plot temperature on the left y-axis
color = 'tab:red'
ax1.set_xlabel('Time', fontsize=12)
ax1.set_ylabel('Temperature (°C)', color=color, fontsize=12)
ax1.plot(time, temp_smoothed, color=color, linewidth=2, label='Temperature (smoothed)')
ax1.tick_params(axis='y', labelcolor=color)
ax1.grid(True, alpha=0.3)

# Create second y-axis for precipitation
ax2 = ax1.twinx()
color = 'tab:blue'
ax2.set_ylabel('Precipitation (mm)', color=color, fontsize=12)
ax2.plot(time, prcp_smoothed, color=color, linewidth=2, label='Precipitation (smoothed)')
ax2.tick_params(axis='y', labelcolor=color)

# Add title and layout
plt.title('Historical Climate Data (Smoothed)', fontsize=14, fontweight='bold')
fig.tight_layout()

# Add legends
ax1.legend(loc='upper left')
ax2.legend(loc='upper right')

plt.show()

# Display some basic statistics
print(f"\nClimate Data Summary:")
print(f"Time period: {time[0]} to {time[-1]}")
print(f"Temperature range: {temp.min():.2f}°C to {temp.max():.2f}°C")
print(f"Mean temperature: {temp.mean():.2f}°C")
print(f"Precipitation range: {prcp.min():.2f} to {prcp.max():.2f} mm")
print(f"Mean precipitation: {prcp.mean():.2f} mm")
# Out:
# Climate Data Summary:
# Time period: 1901-01-01T00:00:00.000000000 to 2019-12-01T00:00:00.000000000
# Temperature range: -13.78°C to 12.20°C
# Mean temperature: 0.09°C
# Precipitation range: 0.00 to 395.17 mm
# Mean precipitation: 93.71 mm

# %% [markdown]
# Running the code has created the following output files:

# %%
from helper import *
import glob

# Find all output files
A = glob.glob('outputs/*/*/output.nc')
print(f"Found {len(A)} output file(s):", A)

if A:
    # Animate the last run
    animate_glacier_evolution(A[-1])
else:
    print("No output.nc files found. Please run the model first.")
# Out:
# Found 5 output file(s): ['outputs/2025-10-29/07-55-48/output.nc', 'outputs/2025-10-29/07-54-32/output.nc', 'outputs/2025-10-29/08-01-24/output.nc', 'outputs/2025-10-29/08-55-37/output.nc', 'outputs/2025-10-29/08-54-22/output.nc']

# %% [markdown]
# ### Analyzing the time series results
#
# Let's examine how the glacier evolved under the climate scenario:

# %%
from helper import *
import glob
import os

# Find all time series files and select the most recent one
ts_files = sorted(glob.glob('outputs/*/*/output_ts.nc'))

if ts_files:
    # Get the absolute path to ensure it works from any directory
    ts_file = os.path.abspath(ts_files[-1])
    print(f"Found {len(ts_files)} time series file(s). Using: {ts_files[-1]}\n")
    # Analyze the time series from the most recent run
    analyze_time_series(ts_file)
else:
    print("No output_ts.nc file found. Please run the model first.")
# Out:
# Found 5 time series file(s). Using: outputs/2025-10-29/08-55-37/output_ts.nc
#
# Reading time series data from: /content/glamod/02_notebook/outputs/2025-10-29/08-55-37/output_ts.nc
# ============================================================
# SUMMARY STATISTICS
# ============================================================
#
# Ice Volume:
#   Initial: 1.15 km³
#   Final:   0.65 km³
#   Change:  -0.51 km³
#
# Ice Area:
#   Initial: 14.26 km²
#   Final:   11.05 km²
#   Change:  -3.21 km²
# ============================================================

# %% [markdown]
# ## Third run with IGM (Extra, not necessary for the course)
#
# In a third run, we will bring 2 additional new features (explore the parameter file `params_2.yaml`):
#
# **First new feature:** Using a **custom SMB function** that is defined in the `user` folder. Explore the `user` folder and the parameter file `params_2.yaml` to see how custom code can be integrated.
#
# **Second new feature:** We activate a particle tracking module to simulate the displacement of virtual particles within the ice flow. These particles may represent debris or sediments that are transported by the glacier and are responsible for the formation of moraines. Our goal is to model the formation of the main moraine that developed during the Little Ice Age when the glacier reached its maximum extent.
#
# To achieve this, we have added in `params_2.yaml` two modules: `vert_flow` and `particles`. The `vert_flow` module computes vertical velocities (which is not done by default as it is not usually required), while the `particles` module tracks the trajectory of individual particles. It is possible to visualize the moraine formed by looking at the file `velbar_mag-XXXX.0.png`.
#
# Run the following command:

# %%
! igm_run +experiment=params_2
# Out:
# 2025-10-29 09:01:17.050196: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:485] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2025-10-29 09:01:17.070480: E external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:8454] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2025-10-29 09:01:17.077260: E external/local_xla/xla/stream_executor/cuda/cuda_blas.cc:1452] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2025-10-29 09:01:17.093614: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2025-10-29 09:01:18.236150: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# I0000 00:00:1761728481.613866   20923 cuda_executor.cc:1015] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# I0000 00:00:1761728481.661421   20923 cuda_executor.cc:1015] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# I0000 00:00:1761728481.661806   20923 cuda_executor.cc:1015] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# -------------------------------------------------------------------CUDA Enviroment--------------------------------------------------------------------
# {
#   "cpu_compiler": "/usr/lib/llvm-17/bin/clang",
#   "cuda_version": "12.3",
#   "cudnn_version": "8",
#   "is_cuda_build": true,
#   "is_rocm_build": false,
#   "is_tensorrt_build": true
# }
# ----------------------------------------------------------------Available GPU Devices-----------------------------------------------------------------
# I0000 00:00:1761728481.662343   20923 cuda_executor.cc:1015] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# {
#   "gpu_id": "/physical_device:GPU:0",
#   "device_type": "GPU",
#   "compute_capability": [
#     7,
#     5
#   ],
#   "device_name": "Tesla T4"
# }
# ------------------------------------------------------------------------------------------------------------------------------------------------------
# [PhysicalDevice(name='/physical_device:GPU:0', device_type='GPU')]
# I0000 00:00:1761728481.663385   20923 cuda_executor.cc:1015] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# I0000 00:00:1761728481.663654   20923 cuda_executor.cc:1015] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# I0000 00:00:1761728481.663911   20923 cuda_executor.cc:1015] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# I0000 00:00:1761728481.851616   20923 cuda_executor.cc:1015] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# I0000 00:00:1761728481.852029   20923 cuda_executor.cc:1015] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# I0000 00:00:1761728481.852265   20923 cuda_executor.cc:1015] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2025-10-29 09:01:21.852415: I tensorflow/core/common_runtime/gpu/gpu_device.cc:2021] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 13942 MB memory:  -> device: 0, name: Tesla T4, pci bus id: 0000:00:04.0, compute capability: 7.5
# 1 Physical GPUs, 1 Logical GPU
# ----------------------------------------------------------------------------------------------------
# -------------------------------------------INPUTS Modules-------------------------------------------
#  0: <module 'igm.inputs.oggm_shop' from '/usr/local/lib/python3.12/dist-packages/igm/inputs/oggm_shop/__init__.py'>
#  1: <module 'igm.inputs.local' from '/usr/local/lib/python3.12/dist-packages/igm/inputs/local.py'>
# -----------------------------------------PROCESSES Modules------------------------------------------
#  0: <module 'mysmb' from '/content/glamod/02_notebook/user/code/processes/mysmb.py'>
#  1: <module 'igm.processes.iceflow' from '/usr/local/lib/python3.12/dist-packages/igm/processes/iceflow/__init__.py'>
#  2: <module 'igm.processes.time' from '/usr/local/lib/python3.12/dist-packages/igm/processes/time/__init__.py'>
#  3: <module 'igm.processes.thk' from '/usr/local/lib/python3.12/dist-packages/igm/processes/thk/__init__.py'>
#  4: <module 'igm.processes.vert_flow' from '/usr/local/lib/python3.12/dist-packages/igm/processes/vert_flow/__init__.py'>
#  5: <module 'igm.processes.particles' from '/usr/local/lib/python3.12/dist-packages/igm/processes/particles/__init__.py'>
# ------------------------------------------OUTPUTS Modules-------------------------------------------
#  0: <module 'igm.outputs.local' from '/usr/local/lib/python3.12/dist-packages/igm/outputs/local.py'>
#  1: <module 'igm.outputs.plot2d' from '/usr/local/lib/python3.12/dist-packages/igm/outputs/plot2d.py'>
# ----------------------------------------------------------------------------------------------------
# Found pretrained emulator in the igm package: pinnbp_10_4_cnn_16_32_2_1_a
# /usr/local/lib/python3.12/dist-packages/keras/src/layers/activations/leaky_relu.py:41: UserWarning: Argument `alpha` is deprecated. Use `negative_slope` instead.
#   warnings.warn(
# Model: "model"
# ┏━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)        ┃ Output Shape      ┃    Param # ┃ Connected to      ┃
# ┡━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━┩
# │ input_1             │ (None, None,      │          0 │ -                 │
# │ (InputLayer)        │ None, 5)          │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d (Conv2D)     │ (None, None,      │      1,472 │ input_1[0][0]     │
# │                     │ None, 32)         │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ leaky_re_lu         │ (None, None,      │          0 │ conv2d[0][0],     │
# │ (LeakyReLU)         │ None, 32)         │            │ conv2d_1[0][0],   │
# │                     │                   │            │ conv2d_2[0][0],   │
# │                     │                   │            │ conv2d_3[0][0],   │
# │                     │                   │            │ conv2d_4[0][0],   │
# │                     │                   │            │ conv2d_5[0][0],   │
# │                     │                   │            │ conv2d_6[0][0],   │
# │                     │                   │            │ conv2d_7[0][0],   │
# │                     │                   │            │ conv2d_8[0][0],   │
# │                     │                   │            │ conv2d_9[0][0],   │
# │                     │                   │            │ conv2d_10[0][0],  │
# │                     │                   │            │ conv2d_11[0][0],  │
# │                     │                   │            │ conv2d_12[0][0],  │
# │                     │                   │            │ conv2d_13[0][0],  │
# │                     │                   │            │ conv2d_14[0][0],  │
# │                     │                   │            │ conv2d_15[0][0]   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dropout (Dropout)   │ (None, None,      │          0 │ leaky_re_lu[0][0] │
# │                     │ None, 32)         │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_1 (Conv2D)   │ (None, None,      │      9,248 │ dropout[0][0]     │
# │                     │ None, 32)         │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dropout_1 (Dropout) │ (None, None,      │          0 │ leaky_re_lu[1][0] │
# │                     │ None, 32)         │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_2 (Conv2D)   │ (None, None,      │      9,248 │ dropout_1[0][0]   │
# │                     │ None, 32)         │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dropout_2 (Dropout) │ (None, None,      │          0 │ leaky_re_lu[2][0] │
# │                     │ None, 32)         │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_3 (Conv2D)   │ (None, None,      │      9,248 │ dropout_2[0][0]   │
# │                     │ None, 32)         │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dropout_3 (Dropout) │ (None, None,      │          0 │ leaky_re_lu[3][0] │
# │                     │ None, 32)         │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_4 (Conv2D)   │ (None, None,      │      9,248 │ dropout_3[0][0]   │
# │                     │ None, 32)         │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dropout_4 (Dropout) │ (None, None,      │          0 │ leaky_re_lu[4][0] │
# │                     │ None, 32)         │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_5 (Conv2D)   │ (None, None,      │      9,248 │ dropout_4[0][0]   │
# │                     │ None, 32)         │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dropout_5 (Dropout) │ (None, None,      │          0 │ leaky_re_lu[5][0] │
# │                     │ None, 32)         │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_6 (Conv2D)   │ (None, None,      │      9,248 │ dropout_5[0][0]   │
# │                     │ None, 32)         │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dropout_6 (Dropout) │ (None, None,      │          0 │ leaky_re_lu[6][0] │
# │                     │ None, 32)         │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_7 (Conv2D)   │ (None, None,      │      9,248 │ dropout_6[0][0]   │
# │                     │ None, 32)         │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dropout_7 (Dropout) │ (None, None,      │          0 │ leaky_re_lu[7][0] │
# │                     │ None, 32)         │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_8 (Conv2D)   │ (None, None,      │      9,248 │ dropout_7[0][0]   │
# │                     │ None, 32)         │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dropout_8 (Dropout) │ (None, None,      │          0 │ leaky_re_lu[8][0] │
# │                     │ None, 32)         │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_9 (Conv2D)   │ (None, None,      │      9,248 │ dropout_8[0][0]   │
# │                     │ None, 32)         │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dropout_9 (Dropout) │ (None, None,      │          0 │ leaky_re_lu[9][0] │
# │                     │ None, 32)         │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_10 (Conv2D)  │ (None, None,      │      9,248 │ dropout_9[0][0]   │
# │                     │ None, 32)         │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dropout_10          │ (None, None,      │          0 │ leaky_re_lu[10][… │
# │ (Dropout)           │ None, 32)         │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_11 (Conv2D)  │ (None, None,      │      9,248 │ dropout_10[0][0]  │
# │                     │ None, 32)         │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dropout_11          │ (None, None,      │          0 │ leaky_re_lu[11][… │
# │ (Dropout)           │ None, 32)         │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_12 (Conv2D)  │ (None, None,      │      9,248 │ dropout_11[0][0]  │
# │                     │ None, 32)         │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dropout_12          │ (None, None,      │          0 │ leaky_re_lu[12][… │
# │ (Dropout)           │ None, 32)         │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_13 (Conv2D)  │ (None, None,      │      9,248 │ dropout_12[0][0]  │
# │                     │ None, 32)         │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dropout_13          │ (None, None,      │          0 │ leaky_re_lu[13][… │
# │ (Dropout)           │ None, 32)         │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_14 (Conv2D)  │ (None, None,      │      9,248 │ dropout_13[0][0]  │
# │                     │ None, 32)         │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dropout_14          │ (None, None,      │          0 │ leaky_re_lu[14][… │
# │ (Dropout)           │ None, 32)         │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_15 (Conv2D)  │ (None, None,      │      9,248 │ dropout_14[0][0]  │
# │                     │ None, 32)         │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dropout_15          │ (None, None,      │          0 │ leaky_re_lu[15][… │
# │ (Dropout)           │ None, 32)         │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_16 (Conv2D)  │ (None, None,      │        660 │ dropout_15[0][0]  │
# │                     │ None, 20)         │            │                   │
# └─────────────────────┴───────────────────┴────────────┴───────────────────┘
#  Total params: 140,852 (550.20 KB)
#  Trainable params: 140,852 (550.20 KB)
#  Non-trainable params: 0 (0.00 B)
# None
# 2025-10-29 09:01:23.809604: I external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:531] Loaded cuDNN version 8907
# W0000 00:00:1761728483.885850   20923 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1761728483.926051   20923 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1761728483.927621   20923 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1761728483.928833   20923 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1761728483.930052   20923 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1761728483.931283   20923 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1761728483.932557   20923 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1761728483.938909   20923 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1761728483.940214   20923 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1761728483.941490   20923 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1761728483.944221   20923 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1761728483.945555   20923 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1761728483.948349   20923 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1761728483.949765   20923 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1761728483.951246   20923 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1761728483.964203   20923 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1761728483.980616   20923 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1761728484.023301   20923 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1761728484.024944   20923 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1761728484.026559   20923 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1761728484.028181   20923 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1761728484.030157   20923 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1761728484.031704   20923 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1761728484.033413   20923 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1761728484.059067   20923 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1761728484.060951   20923 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1761728484.064522   20923 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1761728484.066434   20923 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1761728484.068344   20923 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1761728484.070835   20923 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1761728484.074872   20923 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1761728484.077271   20923 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1761728484.080313   20923 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1761728484.085878   20923 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1761728484.115167   20923 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# /usr/local/lib/python3.12/dist-packages/tensorflow/python/framework/tensor_util.py:522: RuntimeWarning: overflow encountered in cast
#   nparray = np.array(values, dtype=np_dt)
# W0000 00:00:1761728492.028978   20923 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1761728492.030471   20923 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1761728492.032315   20923 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1761728492.040780   20923 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1761728492.043232   20923 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1761728492.045694   20923 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1761728492.048073   20923 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1761728492.050534   20923 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1761728492.054287   20923 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1761728492.057940   20923 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1761728492.083174   20923 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1761728492.112573   20923 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1761728492.115413   20923 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1761728492.118305   20923 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1761728492.120386   20923 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1761728492.124082   20923 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1761728492.128415   20923 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1761728492.132671   20923 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1761728492.135060   20923 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1761728492.138318   20923 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1761728492.142513   20923 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1761728492.146641   20923 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1761728492.152598   20923 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1761728492.164756   20923 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1761728492.193333   20923 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1761728492.201654   20923 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1761728492.203418   20923 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1761728492.205768   20923 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1761728492.207091   20923 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1761728492.208422   20923 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1761728492.209729   20923 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1761728492.212412   20923 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1761728492.214957   20923 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1761728492.216746   20923 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1761728492.221885   20923 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1761728492.223225   20923 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1761728492.224543   20923 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1761728492.226460   20923 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1761728492.228273   20923 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1761728492.229901   20923 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1761728492.231799   20923 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1761728492.234017   20923 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1761728492.236799   20923 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1761728492.239756   20923 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1761728492.241977   20923 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1761728492.245610   20923 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# IGM , 🕒=09:01:48, 🔄=000100, ⏱ Time=0002018.9 yr, ⏳ Step=0.17 yr, ❄️  Volume=1.37 km³, # Particles=112
# IGM , 🕒=09:02:01, 🔄=000200, ⏱ Time=0002032.5 yr, ⏳ Step=0.11 yr, ❄️  Volume=1.68 km³, # Particles=112
# IGM , 🕒=09:02:13, 🔄=000300, ⏱ Time=0002042.6 yr, ⏳ Step=0.09 yr, ❄️  Volume=1.92 km³, # Particles=112
# IGM , 🕒=09:02:26, 🔄=000400, ⏱ Time=0002051.5 yr, ⏳ Step=0.08 yr, ❄️  Volume=2.10 km³, # Particles=354
# IGM , 🕒=09:02:37, 🔄=000500, ⏱ Time=0002060.0 yr, ⏳ Step=0.08 yr, ❄️  Volume=2.26 km³, # Particles=354
# IGM , 🕒=09:02:50, 🔄=000600, ⏱ Time=0002068.0 yr, ⏳ Step=0.08 yr, ❄️  Volume=2.37 km³, # Particles=354
# IGM , 🕒=09:03:03, 🔄=000700, ⏱ Time=0002075.8 yr, ⏳ Step=0.08 yr, ❄️  Volume=2.47 km³, # Particles=354
# IGM , 🕒=09:03:15, 🔄=000800, ⏱ Time=0002083.9 yr, ⏳ Step=0.08 yr, ❄️  Volume=2.54 km³, # Particles=354
# IGM , 🕒=09:03:28, 🔄=000900, ⏱ Time=0002092.7 yr, ⏳ Step=0.10 yr, ❄️  Volume=2.56 km³, # Particles=354
# IGM , 🕒=09:03:39, 🔄=000976, ⏱ Time=0002100.0 yr, ⏳ Step=0.08 yr, ❄️  Volume=2.50 km³, # Particles=483
